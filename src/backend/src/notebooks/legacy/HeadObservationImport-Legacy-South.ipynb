# %%
import geopandas as gpd
import os

notebook_path = os.getcwd()
if not notebook_path.endswith('/notebooks/legacy'):
  notebook_path = os.path.join(notebook_path, '/notebooks/legacy')

# Read the shapefile
directory = os.path.join(notebook_path, 'assets', 'Mumbwa', 'Head-Observations-South')
filename = 'SADC_south_for_calibration'
gdf = gpd.read_file(os.path.join(directory, filename + '.shp'))

# Print the first few rows of the GeoDataFrame
gdf
# Out:
#       fid  sadc_bhid  long_wgs84  lat_wgs84  elev_m_dem  bh_depth_m  swl_m  \
# 0   12738     858834   27.283350 -16.517830        1166        65.0    6.0
# 1   13138     861399   27.283195 -16.684669        1234        67.5   20.8
# 2   13125     861418   27.366537 -16.518663        1253        79.5   10.1
# 3   13132     861382   27.349867 -16.529592        1257        79.5   16.6
# 4   13129     861391   27.271534 -16.530432        1168       103.5    8.8
# 5   13118     861441   28.066557 -16.151293        1365        55.5    6.5
# 6   12741     858905   27.466690 -16.367840        1130        61.0    7.8
# 7   12682     858817   26.983340 -16.534490        1183        80.0    5.3
# 8   13163     860181   27.206533 -16.731246        1234        85.5   15.9
# 9   13128     860187   27.246534 -16.610585        1188       102.0   11.1
# 10  12744     859056   27.183340 -16.501160        1151        51.8   22.9
# 11  12739     858769   27.583350 -16.151190        1081        60.0    4.0
# 12  13136     861442   27.316536 -16.664581        1292        67.5   20.9
# 13  13140     860202   27.208193 -16.651252        1205        67.5   11.0
# 14  13116     861470   28.053556 -16.180120        1275        37.5    3.3
# 15  12777     858978   27.016680 -16.484490        1125        43.3   10.1
# 16  13130     861490   27.300365 -16.569429        1227        61.5   16.3
# 17  13127     861509   27.213193 -16.602926        1168        67.5   13.5
# 18  13131     861513   27.280495 -16.581438        1197        79.5   13.7
# 19  13119     861540   28.016215 -16.217957        1306        49.5    7.3
# 20  13099     861541   28.008215 -16.189290        1283        55.5   22.9
# 21  13126     861602   27.266534 -16.734575        1277        73.5   13.1
# 22  13141     861595   27.281535 -16.728746        1304        85.5   22.2
# 23  12697     858942   26.883330 -16.651150        1268        50.3    9.0
# 24  13115     860307   28.028215 -16.225217        1332        97.5   20.5
# 25  13157     860320   26.951135 -16.732965        1312        67.5   13.4
# 26  13139     860319   27.306535 -16.667921        1274        83.0    7.5
# 27  13137     860329   27.316536 -16.682920        1293        50.0    9.4
# 28  13133     860330   27.366537 -16.588207        1257        71.0    9.3
# 29  13143     860341   27.199862 -16.723416        1212        91.5   29.1
# 30  12731     858910   27.833360 -16.184510        1147        64.7    7.9
# 31  12681     858901   27.500020 -16.501160        1195        61.0    7.6
# 32  12687     858604   27.450020 -16.267850        1101        72.0   11.3
#
#     yield_l_s           lith_subm  \
# 0         0.1              Gneiss
# 1         0.2             NO_DATA
# 2         0.2             NO_DATA
# 3         0.2             NO_DATA
# 4         0.2             NO_DATA
# 5         0.3             NO_DATA
# 6         0.3              Schist
# 7         0.3    Granite & Gneiss
# 8         0.3             NO_DATA
# 9         0.3             NO_DATA
# 10        0.4    Granite & Schist
# 11        0.4  Quartzite & Schist
# 12        0.4             NO_DATA
# 13        0.4             NO_DATA
# 14        0.5             NO_DATA
# 15        0.5             Granite
# 16        0.6             NO_DATA
# 17        0.7             NO_DATA
# 18        0.7             NO_DATA
# 19        0.9             NO_DATA
# 20        0.9             NO_DATA
# 21        1.3             NO_DATA
# 22        1.3             NO_DATA
# 23        1.4             NO_DATA
# 24        1.4             NO_DATA
# 25        1.5             NO_DATA
# 26        1.5             NO_DATA
# 27        1.6             NO_DATA
# 28        1.6             NO_DATA
# 29        1.6             NO_DATA
# 30        2.5              Schist
# 31        3.0             Granite
# 32        5.0  Sand soil & Schist
#
#                                             hgm_litho     hgm_aqtype  \
# 0    Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 1    Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 2    Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 3    Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 4    Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 5                              Dolomite and limestone          Karst
# 6    Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 7    Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 8    Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 9    Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 10   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 11  Paragneiss, quartzite, schiste, phyllite, amph...       Fissured
# 12   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 13   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 14                             Dolomite and limestone          Karst
# 15   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 16   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 17   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 18   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 19   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 20                             Dolomite and limestone          Karst
# 21   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 22   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 23   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 24   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 25   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 26   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 27   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 28  Paragneiss, quartzite, schiste, phyllite, amph...  Low potential
# 29   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 30  Paragneiss, quartzite, schiste, phyllite, amph...       Fissured
# 31   Granite, syenite,  gabbro, gneiss and migmatites  Low potential
# 32  Paragneiss, quartzite, schiste, phyllite, amph...       Fissured
#
#                                hgm_produc  Layer  Obs_head  \
# 0                 Generally low potential      2    1160.0
# 1                 Generally low potential      2    1213.2
# 2                 Generally low potential      2    1242.9
# 3                 Generally low potential      2    1240.4
# 4                 Generally low potential      2    1159.2
# 5      Karst aquifers, moderate potential      2    1358.5
# 6                 Generally low potential      2    1122.2
# 7                 Generally low potential      2    1177.7
# 8                 Generally low potential      2    1218.1
# 9                 Generally low potential      2    1176.9
# 10                Generally low potential      2    1128.1
# 11  Fissured aquifers, moderate potential      2    1077.0
# 12                Generally low potential      2    1271.1
# 13                Generally low potential      2    1194.0
# 14     Karst aquifers, moderate potential      2    1271.7
# 15                Generally low potential      2    1114.9
# 16                Generally low potential      2    1210.7
# 17                Generally low potential      2    1154.5
# 18                Generally low potential      2    1183.3
# 19                Generally low potential      2    1298.7
# 20     Karst aquifers, moderate potential      2    1260.1
# 21                Generally low potential      2    1263.9
# 22                Generally low potential      2    1281.8
# 23                Generally low potential      2    1259.0
# 24                Generally low potential      2    1311.5
# 25                Generally low potential      2    1298.6
# 26                Generally low potential      2    1266.5
# 27                Generally low potential      2    1283.6
# 28                Generally low potential      2    1247.7
# 29                Generally low potential      2    1182.9
# 30  Fissured aquifers, moderate potential      2    1139.1
# 31                Generally low potential      2    1187.4
# 32  Fissured aquifers, moderate potential      2    1089.7
#
#                       geometry
# 0   POINT (27.28335 -16.51783)
# 1   POINT (27.28319 -16.68467)
# 2   POINT (27.36654 -16.51866)
# 3   POINT (27.34987 -16.52959)
# 4   POINT (27.27153 -16.53043)
# 5   POINT (28.06656 -16.15129)
# 6   POINT (27.46669 -16.36784)
# 7   POINT (26.98334 -16.53449)
# 8   POINT (27.20653 -16.73125)
# 9   POINT (27.24653 -16.61059)
# 10  POINT (27.18334 -16.50116)
# 11  POINT (27.58335 -16.15119)
# 12  POINT (27.31654 -16.66458)
# 13  POINT (27.20819 -16.65125)
# 14  POINT (28.05356 -16.18012)
# 15  POINT (27.01668 -16.48449)
# 16  POINT (27.30037 -16.56943)
# 17  POINT (27.21319 -16.60293)
# 18  POINT (27.28049 -16.58144)
# 19  POINT (28.01622 -16.21796)
# 20  POINT (28.00821 -16.18929)
# 21  POINT (27.26653 -16.73458)
# 22  POINT (27.28153 -16.72875)
# 23  POINT (26.88333 -16.65115)
# 24  POINT (28.02822 -16.22522)
# 25  POINT (26.95114 -16.73297)
# 26  POINT (27.30654 -16.66792)
# 27  POINT (27.31654 -16.68292)
# 28  POINT (27.36654 -16.58821)
# 29  POINT (27.19986 -16.72342)
# 30  POINT (27.83336 -16.18451)
# 31  POINT (27.50002 -16.50116)
# 32  POINT (27.45002 -16.26785)

# %%
geojson = gdf.to_crs(epsg=4326).__geo_interface__
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'id': '0',
#    'type': 'Feature',
#    'properties': {'fid': 12738,
#     'sadc_bhid': 858834,
#     'long_wgs84': 27.28335,
#     'lat_wgs84': -16.51783,
#     'elev_m_dem': 1166,
#     'bh_depth_m': 65.0,
#     'swl_m': 6.0,
#     'yield_l_s': 0.1,
#     'lith_subm': 'Gneiss',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1160.0},
#    'geometry': {'type': 'Point', 'coordinates': (27.28335, -16.51783)},
#    'bbox': (27.28335, -16.51783, 27.28335, -16.51783)},
#   {'id': '1',
#    'type': 'Feature',
#    'properties': {'fid': 13138,
#     'sadc_bhid': 861399,
#     'long_wgs84': 27.2831946,
#     'lat_wgs84': -16.6846695,
#     'elev_m_dem': 1234,
#     'bh_depth_m': 67.5,
#     'swl_m': 20.8,
#     'yield_l_s': 0.2,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1213.2},
#    'geometry': {'type': 'Point', 'coordinates': (27.2831946, -16.6846695)},
#    'bbox': (27.2831946, -16.6846695, 27.2831946, -16.6846695)},
#   {'id': '2',
#    'type': 'Feature',
#    'properties': {'fid': 13125,
#     'sadc_bhid': 861418,
#     'long_wgs84': 27.3665371,
#     'lat_wgs84': -16.5186628,
#     'elev_m_dem': 1253,
#     'bh_depth_m': 79.5,
#     'swl_m': 10.1,
#     'yield_l_s': 0.2,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1242.9},
#    'geometry': {'type': 'Point', 'coordinates': (27.3665371, -16.5186628)},
#    'bbox': (27.3665371, -16.5186628, 27.3665371, -16.5186628)},
#   {'id': '3',
#    'type': 'Feature',
#    'properties': {'fid': 13132,
#     'sadc_bhid': 861382,
#     'long_wgs84': 27.3498666,
#     'lat_wgs84': -16.5295919,
#     'elev_m_dem': 1257,
#     'bh_depth_m': 79.5,
#     'swl_m': 16.6,
#     'yield_l_s': 0.2,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1240.4},
#    'geometry': {'type': 'Point', 'coordinates': (27.3498666, -16.5295919)},
#    'bbox': (27.3498666, -16.5295919, 27.3498666, -16.5295919)},
#   {'id': '4',
#    'type': 'Feature',
#    'properties': {'fid': 13129,
#     'sadc_bhid': 861391,
#     'long_wgs84': 27.2715344,
#     'lat_wgs84': -16.5304318,
#     'elev_m_dem': 1168,
#     'bh_depth_m': 103.5,
#     'swl_m': 8.800000000000002,
#     'yield_l_s': 0.2,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1159.2},
#    'geometry': {'type': 'Point', 'coordinates': (27.2715344, -16.5304318)},
#    'bbox': (27.2715344, -16.5304318, 27.2715344, -16.5304318)},
#   {'id': '5',
#    'type': 'Feature',
#    'properties': {'fid': 13118,
#     'sadc_bhid': 861441,
#     'long_wgs84': 28.0665565,
#     'lat_wgs84': -16.1512927,
#     'elev_m_dem': 1365,
#     'bh_depth_m': 55.5,
#     'swl_m': 6.5,
#     'yield_l_s': 0.3,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Dolomite and limestone',
#     'hgm_aqtype': 'Karst',
#     'hgm_produc': 'Karst aquifers, moderate potential',
#     'Layer': 2,
#     'Obs_head': 1358.5},
#    'geometry': {'type': 'Point', 'coordinates': (28.0665565, -16.1512927)},
#    'bbox': (28.0665565, -16.1512927, 28.0665565, -16.1512927)},
#   {'id': '6',
#    'type': 'Feature',
#    'properties': {'fid': 12741,
#     'sadc_bhid': 858905,
#     'long_wgs84': 27.46669,
#     'lat_wgs84': -16.36784,
#     'elev_m_dem': 1130,
#     'bh_depth_m': 61.0,
#     'swl_m': 7.8,
#     'yield_l_s': 0.3,
#     'lith_subm': 'Schist',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1122.2},
#    'geometry': {'type': 'Point', 'coordinates': (27.46669, -16.36784)},
#    'bbox': (27.46669, -16.36784, 27.46669, -16.36784)},
#   {'id': '7',
#    'type': 'Feature',
#    'properties': {'fid': 12682,
#     'sadc_bhid': 858817,
#     'long_wgs84': 26.98334,
#     'lat_wgs84': -16.53449,
#     'elev_m_dem': 1183,
#     'bh_depth_m': 80.0,
#     'swl_m': 5.3,
#     'yield_l_s': 0.3,
#     'lith_subm': 'Granite & Gneiss',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1177.7},
#    'geometry': {'type': 'Point', 'coordinates': (26.98334, -16.53449)},
#    'bbox': (26.98334, -16.53449, 26.98334, -16.53449)},
#   {'id': '8',
#    'type': 'Feature',
#    'properties': {'fid': 13163,
#     'sadc_bhid': 860181,
#     'long_wgs84': 27.2065325,
#     'lat_wgs84': -16.7312457,
#     'elev_m_dem': 1234,
#     'bh_depth_m': 85.5,
#     'swl_m': 15.9,
#     'yield_l_s': 0.3,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1218.1},
#    'geometry': {'type': 'Point', 'coordinates': (27.2065325, -16.7312457)},
#    'bbox': (27.2065325, -16.7312457, 27.2065325, -16.7312457)},
#   {'id': '9',
#    'type': 'Feature',
#    'properties': {'fid': 13128,
#     'sadc_bhid': 860187,
#     'long_wgs84': 27.2465337,
#     'lat_wgs84': -16.6105854,
#     'elev_m_dem': 1188,
#     'bh_depth_m': 102.0,
#     'swl_m': 11.1,
#     'yield_l_s': 0.3,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1176.9},
#    'geometry': {'type': 'Point', 'coordinates': (27.2465337, -16.6105854)},
#    'bbox': (27.2465337, -16.6105854, 27.2465337, -16.6105854)},
#   {'id': '10',
#    'type': 'Feature',
#    'properties': {'fid': 12744,
#     'sadc_bhid': 859056,
#     'long_wgs84': 27.18334,
#     'lat_wgs84': -16.50116,
#     'elev_m_dem': 1151,
#     'bh_depth_m': 51.8,
#     'swl_m': 22.9,
#     'yield_l_s': 0.4,
#     'lith_subm': 'Granite & Schist',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1128.1},
#    'geometry': {'type': 'Point', 'coordinates': (27.18334, -16.50116)},
#    'bbox': (27.18334, -16.50116, 27.18334, -16.50116)},
#   {'id': '11',
#    'type': 'Feature',
#    'properties': {'fid': 12739,
#     'sadc_bhid': 858769,
#     'long_wgs84': 27.58335,
#     'lat_wgs84': -16.15119,
#     'elev_m_dem': 1081,
#     'bh_depth_m': 60.0,
#     'swl_m': 4.0,
#     'yield_l_s': 0.4,
#     'lith_subm': 'Quartzite & Schist',
#     'hgm_litho': 'Paragneiss, quartzite, schiste, phyllite, amphibolite',
#     'hgm_aqtype': 'Fissured',
#     'hgm_produc': 'Fissured aquifers, moderate potential',
#     'Layer': 2,
#     'Obs_head': 1077.0},
#    'geometry': {'type': 'Point', 'coordinates': (27.58335, -16.15119)},
#    'bbox': (27.58335, -16.15119, 27.58335, -16.15119)},
#   {'id': '12',
#    'type': 'Feature',
#    'properties': {'fid': 13136,
#     'sadc_bhid': 861442,
#     'long_wgs84': 27.3165356,
#     'lat_wgs84': -16.6645811,
#     'elev_m_dem': 1292,
#     'bh_depth_m': 67.5,
#     'swl_m': 20.9,
#     'yield_l_s': 0.4,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1271.1},
#    'geometry': {'type': 'Point', 'coordinates': (27.3165356, -16.6645811)},
#    'bbox': (27.3165356, -16.6645811, 27.3165356, -16.6645811)},
#   {'id': '13',
#    'type': 'Feature',
#    'properties': {'fid': 13140,
#     'sadc_bhid': 860202,
#     'long_wgs84': 27.2081926,
#     'lat_wgs84': -16.6512521,
#     'elev_m_dem': 1205,
#     'bh_depth_m': 67.5,
#     'swl_m': 11.0,
#     'yield_l_s': 0.4,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1194.0},
#    'geometry': {'type': 'Point', 'coordinates': (27.2081926, -16.6512521)},
#    'bbox': (27.2081926, -16.6512521, 27.2081926, -16.6512521)},
#   {'id': '14',
#    'type': 'Feature',
#    'properties': {'fid': 13116,
#     'sadc_bhid': 861470,
#     'long_wgs84': 28.0535562,
#     'lat_wgs84': -16.1801204,
#     'elev_m_dem': 1275,
#     'bh_depth_m': 37.5,
#     'swl_m': 3.3,
#     'yield_l_s': 0.5,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Dolomite and limestone',
#     'hgm_aqtype': 'Karst',
#     'hgm_produc': 'Karst aquifers, moderate potential',
#     'Layer': 2,
#     'Obs_head': 1271.7},
#    'geometry': {'type': 'Point', 'coordinates': (28.0535562, -16.1801204)},
#    'bbox': (28.0535562, -16.1801204, 28.0535562, -16.1801204)},
#   {'id': '15',
#    'type': 'Feature',
#    'properties': {'fid': 12777,
#     'sadc_bhid': 858978,
#     'long_wgs84': 27.01668,
#     'lat_wgs84': -16.48449,
#     'elev_m_dem': 1125,
#     'bh_depth_m': 43.3,
#     'swl_m': 10.1,
#     'yield_l_s': 0.5,
#     'lith_subm': 'Granite',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1114.9},
#    'geometry': {'type': 'Point', 'coordinates': (27.01668, -16.48449)},
#    'bbox': (27.01668, -16.48449, 27.01668, -16.48449)},
#   {'id': '16',
#    'type': 'Feature',
#    'properties': {'fid': 13130,
#     'sadc_bhid': 861490,
#     'long_wgs84': 27.3003652,
#     'lat_wgs84': -16.5694287,
#     'elev_m_dem': 1227,
#     'bh_depth_m': 61.5,
#     'swl_m': 16.3,
#     'yield_l_s': 0.6,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1210.7},
#    'geometry': {'type': 'Point', 'coordinates': (27.3003652, -16.5694287)},
#    'bbox': (27.3003652, -16.5694287, 27.3003652, -16.5694287)},
#   {'id': '17',
#    'type': 'Feature',
#    'properties': {'fid': 13127,
#     'sadc_bhid': 861509,
#     'long_wgs84': 27.2131928,
#     'lat_wgs84': -16.602926,
#     'elev_m_dem': 1168,
#     'bh_depth_m': 67.5,
#     'swl_m': 13.5,
#     'yield_l_s': 0.7,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1154.5},
#    'geometry': {'type': 'Point', 'coordinates': (27.2131928, -16.602926)},
#    'bbox': (27.2131928, -16.602926, 27.2131928, -16.602926)},
#   {'id': '18',
#    'type': 'Feature',
#    'properties': {'fid': 13131,
#     'sadc_bhid': 861513,
#     'long_wgs84': 27.2804946,
#     'lat_wgs84': -16.5814377,
#     'elev_m_dem': 1197,
#     'bh_depth_m': 79.5,
#     'swl_m': 13.7,
#     'yield_l_s': 0.7,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1183.3},
#    'geometry': {'type': 'Point', 'coordinates': (27.2804946, -16.5814377)},
#    'bbox': (27.2804946, -16.5814377, 27.2804946, -16.5814377)},
#   {'id': '19',
#    'type': 'Feature',
#    'properties': {'fid': 13119,
#     'sadc_bhid': 861540,
#     'long_wgs84': 28.0162151,
#     'lat_wgs84': -16.2179574,
#     'elev_m_dem': 1306,
#     'bh_depth_m': 49.5,
#     'swl_m': 7.3,
#     'yield_l_s': 0.9,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1298.7},
#    'geometry': {'type': 'Point', 'coordinates': (28.0162151, -16.2179574)},
#    'bbox': (28.0162151, -16.2179574, 28.0162151, -16.2179574)},
#   {'id': '20',
#    'type': 'Feature',
#    'properties': {'fid': 13099,
#     'sadc_bhid': 861541,
#     'long_wgs84': 28.0082149,
#     'lat_wgs84': -16.1892897,
#     'elev_m_dem': 1283,
#     'bh_depth_m': 55.5,
#     'swl_m': 22.9,
#     'yield_l_s': 0.9,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Dolomite and limestone',
#     'hgm_aqtype': 'Karst',
#     'hgm_produc': 'Karst aquifers, moderate potential',
#     'Layer': 2,
#     'Obs_head': 1260.1},
#    'geometry': {'type': 'Point', 'coordinates': (28.0082149, -16.1892897)},
#    'bbox': (28.0082149, -16.1892897, 28.0082149, -16.1892897)},
#   {'id': '21',
#    'type': 'Feature',
#    'properties': {'fid': 13126,
#     'sadc_bhid': 861602,
#     'long_wgs84': 27.2665341,
#     'lat_wgs84': -16.7345755,
#     'elev_m_dem': 1277,
#     'bh_depth_m': 73.5,
#     'swl_m': 13.1,
#     'yield_l_s': 1.3,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1263.9},
#    'geometry': {'type': 'Point', 'coordinates': (27.2665341, -16.7345755)},
#    'bbox': (27.2665341, -16.7345755, 27.2665341, -16.7345755)},
#   {'id': '22',
#    'type': 'Feature',
#    'properties': {'fid': 13141,
#     'sadc_bhid': 861595,
#     'long_wgs84': 27.2815346,
#     'lat_wgs84': -16.728746,
#     'elev_m_dem': 1304,
#     'bh_depth_m': 85.5,
#     'swl_m': 22.2,
#     'yield_l_s': 1.3,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1281.8},
#    'geometry': {'type': 'Point', 'coordinates': (27.2815346, -16.728746)},
#    'bbox': (27.2815346, -16.728746, 27.2815346, -16.728746)},
#   {'id': '23',
#    'type': 'Feature',
#    'properties': {'fid': 12697,
#     'sadc_bhid': 858942,
#     'long_wgs84': 26.88333,
#     'lat_wgs84': -16.65115,
#     'elev_m_dem': 1268,
#     'bh_depth_m': 50.3,
#     'swl_m': 9.0,
#     'yield_l_s': 1.4,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1259.0},
#    'geometry': {'type': 'Point', 'coordinates': (26.88333, -16.65115)},
#    'bbox': (26.88333, -16.65115, 26.88333, -16.65115)},
#   {'id': '24',
#    'type': 'Feature',
#    'properties': {'fid': 13115,
#     'sadc_bhid': 860307,
#     'long_wgs84': 28.0282154,
#     'lat_wgs84': -16.2252168,
#     'elev_m_dem': 1332,
#     'bh_depth_m': 97.5,
#     'swl_m': 20.5,
#     'yield_l_s': 1.4,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1311.5},
#    'geometry': {'type': 'Point', 'coordinates': (28.0282154, -16.2252168)},
#    'bbox': (28.0282154, -16.2252168, 28.0282154, -16.2252168)},
#   {'id': '25',
#    'type': 'Feature',
#    'properties': {'fid': 13157,
#     'sadc_bhid': 860320,
#     'long_wgs84': 26.9511355,
#     'lat_wgs84': -16.7329654,
#     'elev_m_dem': 1312,
#     'bh_depth_m': 67.5,
#     'swl_m': 13.4,
#     'yield_l_s': 1.5,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1298.6},
#    'geometry': {'type': 'Point', 'coordinates': (26.9511355, -16.7329654)},
#    'bbox': (26.9511355, -16.7329654, 26.9511355, -16.7329654)},
#   {'id': '26',
#    'type': 'Feature',
#    'properties': {'fid': 13139,
#     'sadc_bhid': 860319,
#     'long_wgs84': 27.3065353,
#     'lat_wgs84': -16.6679208,
#     'elev_m_dem': 1274,
#     'bh_depth_m': 83.0,
#     'swl_m': 7.5,
#     'yield_l_s': 1.5,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1266.5},
#    'geometry': {'type': 'Point', 'coordinates': (27.3065353, -16.6679208)},
#    'bbox': (27.3065353, -16.6679208, 27.3065353, -16.6679208)},
#   {'id': '27',
#    'type': 'Feature',
#    'properties': {'fid': 13137,
#     'sadc_bhid': 860329,
#     'long_wgs84': 27.3165356,
#     'lat_wgs84': -16.6829197,
#     'elev_m_dem': 1293,
#     'bh_depth_m': 50.0,
#     'swl_m': 9.4,
#     'yield_l_s': 1.6,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1283.6},
#    'geometry': {'type': 'Point', 'coordinates': (27.3165356, -16.6829197)},
#    'bbox': (27.3165356, -16.6829197, 27.3165356, -16.6829197)},
#   {'id': '28',
#    'type': 'Feature',
#    'properties': {'fid': 13133,
#     'sadc_bhid': 860330,
#     'long_wgs84': 27.366537,
#     'lat_wgs84': -16.5882073,
#     'elev_m_dem': 1257,
#     'bh_depth_m': 71.0,
#     'swl_m': 9.3,
#     'yield_l_s': 1.6,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Paragneiss, quartzite, schiste, phyllite, amphibolite',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1247.7},
#    'geometry': {'type': 'Point', 'coordinates': (27.366537, -16.5882073)},
#    'bbox': (27.366537, -16.5882073, 27.366537, -16.5882073)},
#   {'id': '29',
#    'type': 'Feature',
#    'properties': {'fid': 13143,
#     'sadc_bhid': 860341,
#     'long_wgs84': 27.1998623,
#     'lat_wgs84': -16.7234163,
#     'elev_m_dem': 1212,
#     'bh_depth_m': 91.5,
#     'swl_m': 29.1,
#     'yield_l_s': 1.6,
#     'lith_subm': 'NO_DATA',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1182.9},
#    'geometry': {'type': 'Point', 'coordinates': (27.1998623, -16.7234163)},
#    'bbox': (27.1998623, -16.7234163, 27.1998623, -16.7234163)},
#   {'id': '30',
#    'type': 'Feature',
#    'properties': {'fid': 12731,
#     'sadc_bhid': 858910,
#     'long_wgs84': 27.83336,
#     'lat_wgs84': -16.18451,
#     'elev_m_dem': 1147,
#     'bh_depth_m': 64.7,
#     'swl_m': 7.9,
#     'yield_l_s': 2.5,
#     'lith_subm': 'Schist',
#     'hgm_litho': 'Paragneiss, quartzite, schiste, phyllite, amphibolite',
#     'hgm_aqtype': 'Fissured',
#     'hgm_produc': 'Fissured aquifers, moderate potential',
#     'Layer': 2,
#     'Obs_head': 1139.1},
#    'geometry': {'type': 'Point', 'coordinates': (27.83336, -16.18451)},
#    'bbox': (27.83336, -16.18451, 27.83336, -16.18451)},
#   {'id': '31',
#    'type': 'Feature',
#    'properties': {'fid': 12681,
#     'sadc_bhid': 858901,
#     'long_wgs84': 27.50002,
#     'lat_wgs84': -16.50116,
#     'elev_m_dem': 1195,
#     'bh_depth_m': 61.0,
#     'swl_m': 7.6,
#     'yield_l_s': 3.0,
#     'lith_subm': 'Granite',
#     'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#     'hgm_aqtype': 'Low potential',
#     'hgm_produc': 'Generally low potential',
#     'Layer': 2,
#     'Obs_head': 1187.4},
#    'geometry': {'type': 'Point', 'coordinates': (27.50002, -16.50116)},
#    'bbox': (27.50002, -16.50116, 27.50002, -16.50116)},
#   {'id': '32',
#    'type': 'Feature',
#    'properties': {'fid': 12687,
#     'sadc_bhid': 858604,
#     'long_wgs84': 27.45002,
#     'lat_wgs84': -16.26785,
#     'elev_m_dem': 1101,
#     'bh_depth_m': 72.0,
#     'swl_m': 11.3,
#     'yield_l_s': 5.0,
#     'lith_subm': 'Sand soil & Schist',
#     'hgm_litho': 'Paragneiss, quartzite, schiste, phyllite, amphibolite',
#     'hgm_aqtype': 'Fissured',
#     'hgm_produc': 'Fissured aquifers, moderate potential',
#     'Layer': 2,
#     'Obs_head': 1089.7},
#    'geometry': {'type': 'Point', 'coordinates': (27.45002, -16.26785)},
#    'bbox': (27.45002, -16.26785, 27.45002, -16.26785)}],
#  'bbox': (26.88333, -16.7345755, 28.0665565, -16.15119)}

# %%
geojson.keys()
# Out:
# dict_keys(['type', 'features', 'bbox'])

# %%
geojson['features']
# Out:
# [{'id': '0',
#   'type': 'Feature',
#   'properties': {'fid': 12738,
#    'sadc_bhid': 858834,
#    'long_wgs84': 27.28335,
#    'lat_wgs84': -16.51783,
#    'elev_m_dem': 1166,
#    'bh_depth_m': 65.0,
#    'swl_m': 6.0,
#    'yield_l_s': 0.1,
#    'lith_subm': 'Gneiss',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1160.0},
#   'geometry': {'type': 'Point', 'coordinates': (27.28335, -16.51783)},
#   'bbox': (27.28335, -16.51783, 27.28335, -16.51783)},
#  {'id': '1',
#   'type': 'Feature',
#   'properties': {'fid': 13138,
#    'sadc_bhid': 861399,
#    'long_wgs84': 27.2831946,
#    'lat_wgs84': -16.6846695,
#    'elev_m_dem': 1234,
#    'bh_depth_m': 67.5,
#    'swl_m': 20.8,
#    'yield_l_s': 0.2,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1213.2},
#   'geometry': {'type': 'Point', 'coordinates': (27.2831946, -16.6846695)},
#   'bbox': (27.2831946, -16.6846695, 27.2831946, -16.6846695)},
#  {'id': '2',
#   'type': 'Feature',
#   'properties': {'fid': 13125,
#    'sadc_bhid': 861418,
#    'long_wgs84': 27.3665371,
#    'lat_wgs84': -16.5186628,
#    'elev_m_dem': 1253,
#    'bh_depth_m': 79.5,
#    'swl_m': 10.1,
#    'yield_l_s': 0.2,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1242.9},
#   'geometry': {'type': 'Point', 'coordinates': (27.3665371, -16.5186628)},
#   'bbox': (27.3665371, -16.5186628, 27.3665371, -16.5186628)},
#  {'id': '3',
#   'type': 'Feature',
#   'properties': {'fid': 13132,
#    'sadc_bhid': 861382,
#    'long_wgs84': 27.3498666,
#    'lat_wgs84': -16.5295919,
#    'elev_m_dem': 1257,
#    'bh_depth_m': 79.5,
#    'swl_m': 16.6,
#    'yield_l_s': 0.2,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1240.4},
#   'geometry': {'type': 'Point', 'coordinates': (27.3498666, -16.5295919)},
#   'bbox': (27.3498666, -16.5295919, 27.3498666, -16.5295919)},
#  {'id': '4',
#   'type': 'Feature',
#   'properties': {'fid': 13129,
#    'sadc_bhid': 861391,
#    'long_wgs84': 27.2715344,
#    'lat_wgs84': -16.5304318,
#    'elev_m_dem': 1168,
#    'bh_depth_m': 103.5,
#    'swl_m': 8.800000000000002,
#    'yield_l_s': 0.2,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1159.2},
#   'geometry': {'type': 'Point', 'coordinates': (27.2715344, -16.5304318)},
#   'bbox': (27.2715344, -16.5304318, 27.2715344, -16.5304318)},
#  {'id': '5',
#   'type': 'Feature',
#   'properties': {'fid': 13118,
#    'sadc_bhid': 861441,
#    'long_wgs84': 28.0665565,
#    'lat_wgs84': -16.1512927,
#    'elev_m_dem': 1365,
#    'bh_depth_m': 55.5,
#    'swl_m': 6.5,
#    'yield_l_s': 0.3,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Dolomite and limestone',
#    'hgm_aqtype': 'Karst',
#    'hgm_produc': 'Karst aquifers, moderate potential',
#    'Layer': 2,
#    'Obs_head': 1358.5},
#   'geometry': {'type': 'Point', 'coordinates': (28.0665565, -16.1512927)},
#   'bbox': (28.0665565, -16.1512927, 28.0665565, -16.1512927)},
#  {'id': '6',
#   'type': 'Feature',
#   'properties': {'fid': 12741,
#    'sadc_bhid': 858905,
#    'long_wgs84': 27.46669,
#    'lat_wgs84': -16.36784,
#    'elev_m_dem': 1130,
#    'bh_depth_m': 61.0,
#    'swl_m': 7.8,
#    'yield_l_s': 0.3,
#    'lith_subm': 'Schist',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1122.2},
#   'geometry': {'type': 'Point', 'coordinates': (27.46669, -16.36784)},
#   'bbox': (27.46669, -16.36784, 27.46669, -16.36784)},
#  {'id': '7',
#   'type': 'Feature',
#   'properties': {'fid': 12682,
#    'sadc_bhid': 858817,
#    'long_wgs84': 26.98334,
#    'lat_wgs84': -16.53449,
#    'elev_m_dem': 1183,
#    'bh_depth_m': 80.0,
#    'swl_m': 5.3,
#    'yield_l_s': 0.3,
#    'lith_subm': 'Granite & Gneiss',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1177.7},
#   'geometry': {'type': 'Point', 'coordinates': (26.98334, -16.53449)},
#   'bbox': (26.98334, -16.53449, 26.98334, -16.53449)},
#  {'id': '8',
#   'type': 'Feature',
#   'properties': {'fid': 13163,
#    'sadc_bhid': 860181,
#    'long_wgs84': 27.2065325,
#    'lat_wgs84': -16.7312457,
#    'elev_m_dem': 1234,
#    'bh_depth_m': 85.5,
#    'swl_m': 15.9,
#    'yield_l_s': 0.3,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1218.1},
#   'geometry': {'type': 'Point', 'coordinates': (27.2065325, -16.7312457)},
#   'bbox': (27.2065325, -16.7312457, 27.2065325, -16.7312457)},
#  {'id': '9',
#   'type': 'Feature',
#   'properties': {'fid': 13128,
#    'sadc_bhid': 860187,
#    'long_wgs84': 27.2465337,
#    'lat_wgs84': -16.6105854,
#    'elev_m_dem': 1188,
#    'bh_depth_m': 102.0,
#    'swl_m': 11.1,
#    'yield_l_s': 0.3,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1176.9},
#   'geometry': {'type': 'Point', 'coordinates': (27.2465337, -16.6105854)},
#   'bbox': (27.2465337, -16.6105854, 27.2465337, -16.6105854)},
#  {'id': '10',
#   'type': 'Feature',
#   'properties': {'fid': 12744,
#    'sadc_bhid': 859056,
#    'long_wgs84': 27.18334,
#    'lat_wgs84': -16.50116,
#    'elev_m_dem': 1151,
#    'bh_depth_m': 51.8,
#    'swl_m': 22.9,
#    'yield_l_s': 0.4,
#    'lith_subm': 'Granite & Schist',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1128.1},
#   'geometry': {'type': 'Point', 'coordinates': (27.18334, -16.50116)},
#   'bbox': (27.18334, -16.50116, 27.18334, -16.50116)},
#  {'id': '11',
#   'type': 'Feature',
#   'properties': {'fid': 12739,
#    'sadc_bhid': 858769,
#    'long_wgs84': 27.58335,
#    'lat_wgs84': -16.15119,
#    'elev_m_dem': 1081,
#    'bh_depth_m': 60.0,
#    'swl_m': 4.0,
#    'yield_l_s': 0.4,
#    'lith_subm': 'Quartzite & Schist',
#    'hgm_litho': 'Paragneiss, quartzite, schiste, phyllite, amphibolite',
#    'hgm_aqtype': 'Fissured',
#    'hgm_produc': 'Fissured aquifers, moderate potential',
#    'Layer': 2,
#    'Obs_head': 1077.0},
#   'geometry': {'type': 'Point', 'coordinates': (27.58335, -16.15119)},
#   'bbox': (27.58335, -16.15119, 27.58335, -16.15119)},
#  {'id': '12',
#   'type': 'Feature',
#   'properties': {'fid': 13136,
#    'sadc_bhid': 861442,
#    'long_wgs84': 27.3165356,
#    'lat_wgs84': -16.6645811,
#    'elev_m_dem': 1292,
#    'bh_depth_m': 67.5,
#    'swl_m': 20.9,
#    'yield_l_s': 0.4,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1271.1},
#   'geometry': {'type': 'Point', 'coordinates': (27.3165356, -16.6645811)},
#   'bbox': (27.3165356, -16.6645811, 27.3165356, -16.6645811)},
#  {'id': '13',
#   'type': 'Feature',
#   'properties': {'fid': 13140,
#    'sadc_bhid': 860202,
#    'long_wgs84': 27.2081926,
#    'lat_wgs84': -16.6512521,
#    'elev_m_dem': 1205,
#    'bh_depth_m': 67.5,
#    'swl_m': 11.0,
#    'yield_l_s': 0.4,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1194.0},
#   'geometry': {'type': 'Point', 'coordinates': (27.2081926, -16.6512521)},
#   'bbox': (27.2081926, -16.6512521, 27.2081926, -16.6512521)},
#  {'id': '14',
#   'type': 'Feature',
#   'properties': {'fid': 13116,
#    'sadc_bhid': 861470,
#    'long_wgs84': 28.0535562,
#    'lat_wgs84': -16.1801204,
#    'elev_m_dem': 1275,
#    'bh_depth_m': 37.5,
#    'swl_m': 3.3,
#    'yield_l_s': 0.5,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Dolomite and limestone',
#    'hgm_aqtype': 'Karst',
#    'hgm_produc': 'Karst aquifers, moderate potential',
#    'Layer': 2,
#    'Obs_head': 1271.7},
#   'geometry': {'type': 'Point', 'coordinates': (28.0535562, -16.1801204)},
#   'bbox': (28.0535562, -16.1801204, 28.0535562, -16.1801204)},
#  {'id': '15',
#   'type': 'Feature',
#   'properties': {'fid': 12777,
#    'sadc_bhid': 858978,
#    'long_wgs84': 27.01668,
#    'lat_wgs84': -16.48449,
#    'elev_m_dem': 1125,
#    'bh_depth_m': 43.3,
#    'swl_m': 10.1,
#    'yield_l_s': 0.5,
#    'lith_subm': 'Granite',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1114.9},
#   'geometry': {'type': 'Point', 'coordinates': (27.01668, -16.48449)},
#   'bbox': (27.01668, -16.48449, 27.01668, -16.48449)},
#  {'id': '16',
#   'type': 'Feature',
#   'properties': {'fid': 13130,
#    'sadc_bhid': 861490,
#    'long_wgs84': 27.3003652,
#    'lat_wgs84': -16.5694287,
#    'elev_m_dem': 1227,
#    'bh_depth_m': 61.5,
#    'swl_m': 16.3,
#    'yield_l_s': 0.6,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1210.7},
#   'geometry': {'type': 'Point', 'coordinates': (27.3003652, -16.5694287)},
#   'bbox': (27.3003652, -16.5694287, 27.3003652, -16.5694287)},
#  {'id': '17',
#   'type': 'Feature',
#   'properties': {'fid': 13127,
#    'sadc_bhid': 861509,
#    'long_wgs84': 27.2131928,
#    'lat_wgs84': -16.602926,
#    'elev_m_dem': 1168,
#    'bh_depth_m': 67.5,
#    'swl_m': 13.5,
#    'yield_l_s': 0.7,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1154.5},
#   'geometry': {'type': 'Point', 'coordinates': (27.2131928, -16.602926)},
#   'bbox': (27.2131928, -16.602926, 27.2131928, -16.602926)},
#  {'id': '18',
#   'type': 'Feature',
#   'properties': {'fid': 13131,
#    'sadc_bhid': 861513,
#    'long_wgs84': 27.2804946,
#    'lat_wgs84': -16.5814377,
#    'elev_m_dem': 1197,
#    'bh_depth_m': 79.5,
#    'swl_m': 13.7,
#    'yield_l_s': 0.7,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1183.3},
#   'geometry': {'type': 'Point', 'coordinates': (27.2804946, -16.5814377)},
#   'bbox': (27.2804946, -16.5814377, 27.2804946, -16.5814377)},
#  {'id': '19',
#   'type': 'Feature',
#   'properties': {'fid': 13119,
#    'sadc_bhid': 861540,
#    'long_wgs84': 28.0162151,
#    'lat_wgs84': -16.2179574,
#    'elev_m_dem': 1306,
#    'bh_depth_m': 49.5,
#    'swl_m': 7.3,
#    'yield_l_s': 0.9,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1298.7},
#   'geometry': {'type': 'Point', 'coordinates': (28.0162151, -16.2179574)},
#   'bbox': (28.0162151, -16.2179574, 28.0162151, -16.2179574)},
#  {'id': '20',
#   'type': 'Feature',
#   'properties': {'fid': 13099,
#    'sadc_bhid': 861541,
#    'long_wgs84': 28.0082149,
#    'lat_wgs84': -16.1892897,
#    'elev_m_dem': 1283,
#    'bh_depth_m': 55.5,
#    'swl_m': 22.9,
#    'yield_l_s': 0.9,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Dolomite and limestone',
#    'hgm_aqtype': 'Karst',
#    'hgm_produc': 'Karst aquifers, moderate potential',
#    'Layer': 2,
#    'Obs_head': 1260.1},
#   'geometry': {'type': 'Point', 'coordinates': (28.0082149, -16.1892897)},
#   'bbox': (28.0082149, -16.1892897, 28.0082149, -16.1892897)},
#  {'id': '21',
#   'type': 'Feature',
#   'properties': {'fid': 13126,
#    'sadc_bhid': 861602,
#    'long_wgs84': 27.2665341,
#    'lat_wgs84': -16.7345755,
#    'elev_m_dem': 1277,
#    'bh_depth_m': 73.5,
#    'swl_m': 13.1,
#    'yield_l_s': 1.3,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1263.9},
#   'geometry': {'type': 'Point', 'coordinates': (27.2665341, -16.7345755)},
#   'bbox': (27.2665341, -16.7345755, 27.2665341, -16.7345755)},
#  {'id': '22',
#   'type': 'Feature',
#   'properties': {'fid': 13141,
#    'sadc_bhid': 861595,
#    'long_wgs84': 27.2815346,
#    'lat_wgs84': -16.728746,
#    'elev_m_dem': 1304,
#    'bh_depth_m': 85.5,
#    'swl_m': 22.2,
#    'yield_l_s': 1.3,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1281.8},
#   'geometry': {'type': 'Point', 'coordinates': (27.2815346, -16.728746)},
#   'bbox': (27.2815346, -16.728746, 27.2815346, -16.728746)},
#  {'id': '23',
#   'type': 'Feature',
#   'properties': {'fid': 12697,
#    'sadc_bhid': 858942,
#    'long_wgs84': 26.88333,
#    'lat_wgs84': -16.65115,
#    'elev_m_dem': 1268,
#    'bh_depth_m': 50.3,
#    'swl_m': 9.0,
#    'yield_l_s': 1.4,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1259.0},
#   'geometry': {'type': 'Point', 'coordinates': (26.88333, -16.65115)},
#   'bbox': (26.88333, -16.65115, 26.88333, -16.65115)},
#  {'id': '24',
#   'type': 'Feature',
#   'properties': {'fid': 13115,
#    'sadc_bhid': 860307,
#    'long_wgs84': 28.0282154,
#    'lat_wgs84': -16.2252168,
#    'elev_m_dem': 1332,
#    'bh_depth_m': 97.5,
#    'swl_m': 20.5,
#    'yield_l_s': 1.4,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1311.5},
#   'geometry': {'type': 'Point', 'coordinates': (28.0282154, -16.2252168)},
#   'bbox': (28.0282154, -16.2252168, 28.0282154, -16.2252168)},
#  {'id': '25',
#   'type': 'Feature',
#   'properties': {'fid': 13157,
#    'sadc_bhid': 860320,
#    'long_wgs84': 26.9511355,
#    'lat_wgs84': -16.7329654,
#    'elev_m_dem': 1312,
#    'bh_depth_m': 67.5,
#    'swl_m': 13.4,
#    'yield_l_s': 1.5,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1298.6},
#   'geometry': {'type': 'Point', 'coordinates': (26.9511355, -16.7329654)},
#   'bbox': (26.9511355, -16.7329654, 26.9511355, -16.7329654)},
#  {'id': '26',
#   'type': 'Feature',
#   'properties': {'fid': 13139,
#    'sadc_bhid': 860319,
#    'long_wgs84': 27.3065353,
#    'lat_wgs84': -16.6679208,
#    'elev_m_dem': 1274,
#    'bh_depth_m': 83.0,
#    'swl_m': 7.5,
#    'yield_l_s': 1.5,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1266.5},
#   'geometry': {'type': 'Point', 'coordinates': (27.3065353, -16.6679208)},
#   'bbox': (27.3065353, -16.6679208, 27.3065353, -16.6679208)},
#  {'id': '27',
#   'type': 'Feature',
#   'properties': {'fid': 13137,
#    'sadc_bhid': 860329,
#    'long_wgs84': 27.3165356,
#    'lat_wgs84': -16.6829197,
#    'elev_m_dem': 1293,
#    'bh_depth_m': 50.0,
#    'swl_m': 9.4,
#    'yield_l_s': 1.6,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1283.6},
#   'geometry': {'type': 'Point', 'coordinates': (27.3165356, -16.6829197)},
#   'bbox': (27.3165356, -16.6829197, 27.3165356, -16.6829197)},
#  {'id': '28',
#   'type': 'Feature',
#   'properties': {'fid': 13133,
#    'sadc_bhid': 860330,
#    'long_wgs84': 27.366537,
#    'lat_wgs84': -16.5882073,
#    'elev_m_dem': 1257,
#    'bh_depth_m': 71.0,
#    'swl_m': 9.3,
#    'yield_l_s': 1.6,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Paragneiss, quartzite, schiste, phyllite, amphibolite',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1247.7},
#   'geometry': {'type': 'Point', 'coordinates': (27.366537, -16.5882073)},
#   'bbox': (27.366537, -16.5882073, 27.366537, -16.5882073)},
#  {'id': '29',
#   'type': 'Feature',
#   'properties': {'fid': 13143,
#    'sadc_bhid': 860341,
#    'long_wgs84': 27.1998623,
#    'lat_wgs84': -16.7234163,
#    'elev_m_dem': 1212,
#    'bh_depth_m': 91.5,
#    'swl_m': 29.1,
#    'yield_l_s': 1.6,
#    'lith_subm': 'NO_DATA',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1182.9},
#   'geometry': {'type': 'Point', 'coordinates': (27.1998623, -16.7234163)},
#   'bbox': (27.1998623, -16.7234163, 27.1998623, -16.7234163)},
#  {'id': '30',
#   'type': 'Feature',
#   'properties': {'fid': 12731,
#    'sadc_bhid': 858910,
#    'long_wgs84': 27.83336,
#    'lat_wgs84': -16.18451,
#    'elev_m_dem': 1147,
#    'bh_depth_m': 64.7,
#    'swl_m': 7.9,
#    'yield_l_s': 2.5,
#    'lith_subm': 'Schist',
#    'hgm_litho': 'Paragneiss, quartzite, schiste, phyllite, amphibolite',
#    'hgm_aqtype': 'Fissured',
#    'hgm_produc': 'Fissured aquifers, moderate potential',
#    'Layer': 2,
#    'Obs_head': 1139.1},
#   'geometry': {'type': 'Point', 'coordinates': (27.83336, -16.18451)},
#   'bbox': (27.83336, -16.18451, 27.83336, -16.18451)},
#  {'id': '31',
#   'type': 'Feature',
#   'properties': {'fid': 12681,
#    'sadc_bhid': 858901,
#    'long_wgs84': 27.50002,
#    'lat_wgs84': -16.50116,
#    'elev_m_dem': 1195,
#    'bh_depth_m': 61.0,
#    'swl_m': 7.6,
#    'yield_l_s': 3.0,
#    'lith_subm': 'Granite',
#    'hgm_litho': 'Granite, syenite,  gabbro, gneiss and migmatites',
#    'hgm_aqtype': 'Low potential',
#    'hgm_produc': 'Generally low potential',
#    'Layer': 2,
#    'Obs_head': 1187.4},
#   'geometry': {'type': 'Point', 'coordinates': (27.50002, -16.50116)},
#   'bbox': (27.50002, -16.50116, 27.50002, -16.50116)},
#  {'id': '32',
#   'type': 'Feature',
#   'properties': {'fid': 12687,
#    'sadc_bhid': 858604,
#    'long_wgs84': 27.45002,
#    'lat_wgs84': -16.26785,
#    'elev_m_dem': 1101,
#    'bh_depth_m': 72.0,
#    'swl_m': 11.3,
#    'yield_l_s': 5.0,
#    'lith_subm': 'Sand soil & Schist',
#    'hgm_litho': 'Paragneiss, quartzite, schiste, phyllite, amphibolite',
#    'hgm_aqtype': 'Fissured',
#    'hgm_produc': 'Fissured aquifers, moderate potential',
#    'Layer': 2,
#    'Obs_head': 1089.7},
#   'geometry': {'type': 'Point', 'coordinates': (27.45002, -16.26785)},
#   'bbox': (27.45002, -16.26785, 27.45002, -16.26785)}]

# %%
expected_json = {
  "type": "hob",
  "name": "1220",
  "geometry": {
    "type": "Point",
    "coordinates": [
      27.005081,
      -14.99067
    ]
  },
  "layers": [
    0
  ],
  "date_times": [
    "2000-01-01"
  ],
  "sp_values": [
    [
      1215
    ]
  ],
  "is_excluded_from_calculation": False
}

# %%
from morpheus.project.types.geometry import Point
import dataclasses


@dataclasses.dataclass
class HeadObservation:
  type: str
  name: str
  geometry: Point
  layers: list[int]
  well_type: str
  sp_values: list[list[int]]
  is_excluded_from_calculation: bool

  @classmethod
  def from_geojson(cls, geojson):
    properties = geojson['properties']
    name = str(properties['fid'])
    if (geojson["geometry"]) is None:
      print(f'Geometry None for {name}')
      return 
            
    return cls(
      type='hob',
      name=name,
      geometry=Point.from_dict(geojson['geometry']),
      layers=[properties['Layer'] - 1],
      well_type='puw',
      sp_values=[[properties['Obs_head']]],
      is_excluded_from_calculation=False
    )

  def to_dict(self):
    return {
      'type': self.type,
      'name': self.name,
      'geometry': self.geometry.to_dict(),
      'layers': self.layers,
      'date_times': [
        "2000-01-01"
      ],
      'sp_values': self.sp_values,
      'is_excluded_from_calculation': self.is_excluded_from_calculation
    }

# %%
feature = geojson['features'][0]
head_observation = HeadObservation.from_geojson(feature)
head_observation.to_dict()
# Out:
# {'type': 'hob',
#  'name': '12738',
#  'geometry': {'type': 'Point', 'coordinates': (27.28335, -16.51783)},
#  'layers': [1],
#  'date_times': ['2000-01-01'],
#  'sp_values': [[1160.0]],
#  'is_excluded_from_calculation': False}

# %%
head_observations = [HeadObservation.from_geojson(feature).to_dict() for feature in geojson['features'] if feature["geometry"] is not  None]
head_observations
# Out:
# [{'type': 'hob',
#   'name': '12738',
#   'geometry': {'type': 'Point', 'coordinates': (27.28335, -16.51783)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1160.0]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13138',
#   'geometry': {'type': 'Point', 'coordinates': (27.2831946, -16.6846695)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1213.2]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13125',
#   'geometry': {'type': 'Point', 'coordinates': (27.3665371, -16.5186628)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1242.9]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13132',
#   'geometry': {'type': 'Point', 'coordinates': (27.3498666, -16.5295919)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1240.4]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13129',
#   'geometry': {'type': 'Point', 'coordinates': (27.2715344, -16.5304318)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1159.2]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13118',
#   'geometry': {'type': 'Point', 'coordinates': (28.0665565, -16.1512927)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1358.5]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '12741',
#   'geometry': {'type': 'Point', 'coordinates': (27.46669, -16.36784)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1122.2]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '12682',
#   'geometry': {'type': 'Point', 'coordinates': (26.98334, -16.53449)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1177.7]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13163',
#   'geometry': {'type': 'Point', 'coordinates': (27.2065325, -16.7312457)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1218.1]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13128',
#   'geometry': {'type': 'Point', 'coordinates': (27.2465337, -16.6105854)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1176.9]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '12744',
#   'geometry': {'type': 'Point', 'coordinates': (27.18334, -16.50116)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1128.1]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '12739',
#   'geometry': {'type': 'Point', 'coordinates': (27.58335, -16.15119)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1077.0]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13136',
#   'geometry': {'type': 'Point', 'coordinates': (27.3165356, -16.6645811)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1271.1]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13140',
#   'geometry': {'type': 'Point', 'coordinates': (27.2081926, -16.6512521)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1194.0]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13116',
#   'geometry': {'type': 'Point', 'coordinates': (28.0535562, -16.1801204)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1271.7]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '12777',
#   'geometry': {'type': 'Point', 'coordinates': (27.01668, -16.48449)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1114.9]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13130',
#   'geometry': {'type': 'Point', 'coordinates': (27.3003652, -16.5694287)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1210.7]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13127',
#   'geometry': {'type': 'Point', 'coordinates': (27.2131928, -16.602926)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1154.5]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13131',
#   'geometry': {'type': 'Point', 'coordinates': (27.2804946, -16.5814377)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1183.3]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13119',
#   'geometry': {'type': 'Point', 'coordinates': (28.0162151, -16.2179574)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1298.7]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13099',
#   'geometry': {'type': 'Point', 'coordinates': (28.0082149, -16.1892897)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1260.1]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13126',
#   'geometry': {'type': 'Point', 'coordinates': (27.2665341, -16.7345755)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1263.9]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13141',
#   'geometry': {'type': 'Point', 'coordinates': (27.2815346, -16.728746)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1281.8]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '12697',
#   'geometry': {'type': 'Point', 'coordinates': (26.88333, -16.65115)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1259.0]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13115',
#   'geometry': {'type': 'Point', 'coordinates': (28.0282154, -16.2252168)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1311.5]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13157',
#   'geometry': {'type': 'Point', 'coordinates': (26.9511355, -16.7329654)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1298.6]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13139',
#   'geometry': {'type': 'Point', 'coordinates': (27.3065353, -16.6679208)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1266.5]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13137',
#   'geometry': {'type': 'Point', 'coordinates': (27.3165356, -16.6829197)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1283.6]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13133',
#   'geometry': {'type': 'Point', 'coordinates': (27.366537, -16.5882073)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1247.7]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '13143',
#   'geometry': {'type': 'Point', 'coordinates': (27.1998623, -16.7234163)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1182.9]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '12731',
#   'geometry': {'type': 'Point', 'coordinates': (27.83336, -16.18451)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1139.1]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '12681',
#   'geometry': {'type': 'Point', 'coordinates': (27.50002, -16.50116)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1187.4]],
#   'is_excluded_from_calculation': False},
#  {'type': 'hob',
#   'name': '12687',
#   'geometry': {'type': 'Point', 'coordinates': (27.45002, -16.26785)},
#   'layers': [1],
#   'date_times': ['2000-01-01'],
#   'sp_values': [[1089.7]],
#   'is_excluded_from_calculation': False}]

# %%
import simplejson as json
with open(os.path.join(directory, filename + '.json'), 'w') as f:
  json.dump(head_observations, f, ignore_nan=True)
