# %%
import sys

sys.path.insert(0, '..')

# %%
from morpheus.project.types.discretization.spatial import Rotation, LengthUnit, Grid
from morpheus.project.types.geometry import Polygon

polygon = Polygon(
  type='Polygon',
  coordinates=[[
    (13.922514437551428, 50.964720483303836),
    (13.925250781947113, 50.965228748412386),
    (13.925036413951403, 50.96623732041704),
    (13.92222441026388, 50.96609040370362),
    (13.922514437551428, 50.964720483303836)
  ]]
)

rotation = Rotation(20)
length_unit = LengthUnit.meters()
relative_col_coordinates = [0, 0.1, 0.21, 0.22, 0.23, 0.24, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
relative_row_coordinates = [0, 0.2, 0.21, 0.22, 0.23, 0.24, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 1]

grid = Grid.from_polygon_with_relative_coordinates(
  polygon=polygon,
  relative_col_coordinates=relative_col_coordinates,
  relative_row_coordinates=relative_row_coordinates,
  rotation=rotation,
)
polygon
# Out:
# Polygon(coordinates=[[(13.922514437551428, 50.964720483303836), (13.925250781947113, 50.965228748412386), (13.925036413951403, 50.96623732041704), (13.92222441026388, 50.96609040370362), (13.922514437551428, 50.964720483303836)]], type='Polygon')

# %%
import folium

m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

cell_geometries = grid.get_wgs_cell_geometries()

n_x = grid.n_cols()
n_y = grid.n_rows()

for col in range(n_x):
  for row in range(n_y):
    cell_geometry = cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson()).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf8efb28f870eb3bdbe8f9dbce3174b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf8efb28f870eb3bdbe8f9dbce3174b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf8efb28f870eb3bdbe8f9dbce3174b9 = L.map(
#                 &quot;map_cf8efb28f870eb3bdbe8f9dbce3174b9&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5e902c10a4ff35fb0f36047831e94e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5e902c10a4ff35fb0f36047831e94e8.addTo(map_cf8efb28f870eb3bdbe8f9dbce3174b9);
#
#
#
#         function geo_json_8df8642b0cc75a8375ce75e260f78959_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_8df8642b0cc75a8375ce75e260f78959 = L.geoJson(null, {
#                 onEachFeature: geo_json_8df8642b0cc75a8375ce75e260f78959_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_8df8642b0cc75a8375ce75e260f78959_add (data) {
#             geo_json_8df8642b0cc75a8375ce75e260f78959
#                 .addData(data);
#         }
#             geo_json_8df8642b0cc75a8375ce75e260f78959_add({&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_8df8642b0cc75a8375ce75e260f78959.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_8df8642b0cc75a8375ce75e260f78959.addTo(map_cf8efb28f870eb3bdbe8f9dbce3174b9);
#
#
#
#         function geo_json_aa7c432265c1d1202f0587e04d0d13ef_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_aa7c432265c1d1202f0587e04d0d13ef = L.geoJson(null, {
#                 onEachFeature: geo_json_aa7c432265c1d1202f0587e04d0d13ef_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_aa7c432265c1d1202f0587e04d0d13ef_add (data) {
#             geo_json_aa7c432265c1d1202f0587e04d0d13ef
#                 .addData(data);
#         }
#             geo_json_aa7c432265c1d1202f0587e04d0d13ef_add({&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_aa7c432265c1d1202f0587e04d0d13ef.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_aa7c432265c1d1202f0587e04d0d13ef.addTo(map_cf8efb28f870eb3bdbe8f9dbce3174b9);
#
#
#
#         function geo_json_646b199bba299f4838deb2d29dcc42e1_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_646b199bba299f4838deb2d29dcc42e1 = L.geoJson(null, {
#                 onEachFeature: geo_json_646b199bba299f4838deb2d29dcc42e1_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_646b199bba299f4838deb2d29dcc42e1_add (data) {
#             geo_json_646b199bba299f4838deb2d29dcc42e1
#                 .addData(data);
#         }
#             geo_json_646b199bba299f4838deb2d29dcc42e1_add({&quot;coordinates&quot;: [[[13.921948099256786, 50.96570044094772], [13.922248202640281, 50.965769231548464], [13.922256140040822, 50.96575549731223], [13.921956036657328, 50.96568670669115], [13.921948099256786, 50.96570044094772]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_646b199bba299f4838deb2d29dcc42e1.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_646b199bba299f4838deb2d29dcc42e1.addTo(map_cf8efb28f870eb3bdbe8f9dbce3174b9);
#
#
#
#         function geo_json_469e6c98fec37e14acf25b9248d198d5_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_469e6c98fec37e14acf25b9248d198d5 = L.geoJson(null, {
#                 onEachFeature: geo_json_469e6c98fec37e14acf25b9248d198d5_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_469e6c98fec37e14acf25b9248d198d5_add (data) {
#             geo_json_469e6c98fec37e14acf25b9248d198d5
#                 .addData(data);
#         }
#             geo_json_469e6c98fec37e14acf25b9248d198d5_add({&quot;coordinates&quot;

# %%
# Calculate and display cartesian Grid from Grid

cartesian_grid = grid.to_cartesian_grid(grid.n_cols())
cell_geometries = cartesian_grid.get_wgs_cell_geometries()

n_x = cartesian_grid.n_cols()
n_y = cartesian_grid.n_rows()

for col in range(n_x):
  for row in range(n_y):
    cell_geometry = cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson()).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf8efb28f870eb3bdbe8f9dbce3174b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf8efb28f870eb3bdbe8f9dbce3174b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf8efb28f870eb3bdbe8f9dbce3174b9 = L.map(
#                 &quot;map_cf8efb28f870eb3bdbe8f9dbce3174b9&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5e902c10a4ff35fb0f36047831e94e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5e902c10a4ff35fb0f36047831e94e8.addTo(map_cf8efb28f870eb3bdbe8f9dbce3174b9);
#
#
#
#         function geo_json_8df8642b0cc75a8375ce75e260f78959_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_8df8642b0cc75a8375ce75e260f78959 = L.geoJson(null, {
#                 onEachFeature: geo_json_8df8642b0cc75a8375ce75e260f78959_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_8df8642b0cc75a8375ce75e260f78959_add (data) {
#             geo_json_8df8642b0cc75a8375ce75e260f78959
#                 .addData(data);
#         }
#             geo_json_8df8642b0cc75a8375ce75e260f78959_add({&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_8df8642b0cc75a8375ce75e260f78959.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_8df8642b0cc75a8375ce75e260f78959.addTo(map_cf8efb28f870eb3bdbe8f9dbce3174b9);
#
#
#
#         function geo_json_aa7c432265c1d1202f0587e04d0d13ef_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_aa7c432265c1d1202f0587e04d0d13ef = L.geoJson(null, {
#                 onEachFeature: geo_json_aa7c432265c1d1202f0587e04d0d13ef_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_aa7c432265c1d1202f0587e04d0d13ef_add (data) {
#             geo_json_aa7c432265c1d1202f0587e04d0d13ef
#                 .addData(data);
#         }
#             geo_json_aa7c432265c1d1202f0587e04d0d13ef_add({&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_aa7c432265c1d1202f0587e04d0d13ef.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_aa7c432265c1d1202f0587e04d0d13ef.addTo(map_cf8efb28f870eb3bdbe8f9dbce3174b9);
#
#
#
#         function geo_json_646b199bba299f4838deb2d29dcc42e1_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_646b199bba299f4838deb2d29dcc42e1 = L.geoJson(null, {
#                 onEachFeature: geo_json_646b199bba299f4838deb2d29dcc42e1_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_646b199bba299f4838deb2d29dcc42e1_add (data) {
#             geo_json_646b199bba299f4838deb2d29dcc42e1
#                 .addData(data);
#         }
#             geo_json_646b199bba299f4838deb2d29dcc42e1_add({&quot;coordinates&quot;: [[[13.921948099256786, 50.96570044094772], [13.922248202640281, 50.965769231548464], [13.922256140040822, 50.96575549731223], [13.921956036657328, 50.96568670669115], [13.921948099256786, 50.96570044094772]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_646b199bba299f4838deb2d29dcc42e1.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_646b199bba299f4838deb2d29dcc42e1.addTo(map_cf8efb28f870eb3bdbe8f9dbce3174b9);
#
#
#
#         function geo_json_469e6c98fec37e14acf25b9248d198d5_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_469e6c98fec37e14acf25b9248d198d5 = L.geoJson(null, {
#                 onEachFeature: geo_json_469e6c98fec37e14acf25b9248d198d5_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_469e6c98fec37e14acf25b9248d198d5_add (data) {
#             geo_json_469e6c98fec37e14acf25b9248d198d5
#                 .addData(data);
#         }
#             geo_json_469e6c98fec37e14acf25b9248d198d5_add({&quot;coordinates&quot;

# %%
# Calculate and display rotated Grid from Grid

m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

grid_cell_geometries = grid.get_wgs_cell_geometries()
grid_n_x = grid.n_cols()
grid_n_y = grid.n_rows()

style = {"weight": 1, "color": "blue", "fillOpacity": 0}
for col in range(grid_n_x):
  for row in range(grid_n_y):
    cell_geometry = grid_cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson(), style_function=lambda x: style).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8e1b366c888dec8d573cd119bc03c7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8e1b366c888dec8d573cd119bc03c7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8e1b366c888dec8d573cd119bc03c7c = L.map(
#                 &quot;map_f8e1b366c888dec8d573cd119bc03c7c&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ddac4ddd3957a2bc23da5e87192220c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ddac4ddd3957a2bc23da5e87192220c.addTo(map_f8e1b366c888dec8d573cd119bc03c7c);
#
#
#         function geo_json_2b1cf650c9916401dd4ea57c033f5212_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2b1cf650c9916401dd4ea57c033f5212_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_2b1cf650c9916401dd4ea57c033f5212 = L.geoJson(null, {
#                 onEachFeature: geo_json_2b1cf650c9916401dd4ea57c033f5212_onEachFeature,
#
#                 style: geo_json_2b1cf650c9916401dd4ea57c033f5212_styler,
#             ...{
# }
#         });
#
#         function geo_json_2b1cf650c9916401dd4ea57c033f5212_add (data) {
#             geo_json_2b1cf650c9916401dd4ea57c033f5212
#                 .addData(data);
#         }
#             geo_json_2b1cf650c9916401dd4ea57c033f5212_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_2b1cf650c9916401dd4ea57c033f5212.addTo(map_f8e1b366c888dec8d573cd119bc03c7c);
#
#
#         function geo_json_56b9a50043997d309988963a78bed6b9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_56b9a50043997d309988963a78bed6b9_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_56b9a50043997d309988963a78bed6b9 = L.geoJson(null, {
#                 onEachFeature: geo_json_56b9a50043997d309988963a78bed6b9_onEachFeature,
#
#                 style: geo_json_56b9a50043997d309988963a78bed6b9_styler,
#             ...{
# }
#         });
#
#         function geo_json_56b9a50043997d309988963a78bed6b9_add (data) {
#             geo_json_56b9a50043997d309988963a78bed6b9
#                 .addData(data);
#         }
#             geo_json_56b9a50043997d309988963a78bed6b9_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_56b9a50043997d309988963a78bed6b9.addTo(map_f8e1b366c888dec8d573cd119bc03c7c);
#
#
#         function geo_json_07337048739e1309bed0aa9fafda7ddf_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_07337048739e1309bed0aa9fafda7ddf_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_07337048739e1309bed0aa9fafda7ddf = L.geoJson(null, {
#                 onEachFeature: geo_json_07337048739e1309bed0aa9fafda7ddf_onEachFeature,
#
#                 style: geo_json_07337048739e1309bed0aa9fafda7ddf_styler,
#             ...{
# }
#         });
#
#         function geo_json_07337048739e1309bed0aa9fafda7ddf_add (data) {
#             geo_json_07337048739e1309bed0aa9fafda7ddf
#                 .addData(data);
#         }
#             geo_json

# %%
m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

rotated_grid_with_equal_cells = grid.to_grid_with_equal_cells(n_cols=grid_n_x)
rotated_grid_cell_geometries = rotated_grid_with_equal_cells.get_wgs_cell_geometries()

rotated_grid_n_x = rotated_grid_with_equal_cells.n_cols()
rotated_grid_n_y = rotated_grid_with_equal_cells.n_rows()

style = {"weight": 1.5, "color": "red", "fillOpacity": 0}
for col in range(rotated_grid_n_x):
  for row in range(rotated_grid_n_y):
    cell_geometry = rotated_grid_cell_geometries[row][col]
    m.add_child(folium.GeoJson(cell_geometry.as_geojson(), style_function=lambda x: style))
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c769c052fc17e5dcc731d575922a9246 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c769c052fc17e5dcc731d575922a9246&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c769c052fc17e5dcc731d575922a9246 = L.map(
#                 &quot;map_c769c052fc17e5dcc731d575922a9246&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de5f3fd585c81494f483cd51e66aae41 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de5f3fd585c81494f483cd51e66aae41.addTo(map_c769c052fc17e5dcc731d575922a9246);
#
#
#         function geo_json_c76427b7780fbe3eece5d4e89c2ee891_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_c76427b7780fbe3eece5d4e89c2ee891_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_c76427b7780fbe3eece5d4e89c2ee891 = L.geoJson(null, {
#                 onEachFeature: geo_json_c76427b7780fbe3eece5d4e89c2ee891_onEachFeature,
#
#                 style: geo_json_c76427b7780fbe3eece5d4e89c2ee891_styler,
#             ...{
# }
#         });
#
#         function geo_json_c76427b7780fbe3eece5d4e89c2ee891_add (data) {
#             geo_json_c76427b7780fbe3eece5d4e89c2ee891
#                 .addData(data);
#         }
#             geo_json_c76427b7780fbe3eece5d4e89c2ee891_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.921995777692256, 50.966037996229026], [13.922075151697669, 50.96590065447864], [13.92186078785084, 50.965851517501946], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_c76427b7780fbe3eece5d4e89c2ee891.addTo(map_c769c052fc17e5dcc731d575922a9246);
#
#
#         function geo_json_bef8c9db6e91f1266ca3aed1701867b9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_bef8c9db6e91f1266ca3aed1701867b9_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_bef8c9db6e91f1266ca3aed1701867b9 = L.geoJson(null, {
#                 onEachFeature: geo_json_bef8c9db6e91f1266ca3aed1701867b9_onEachFeature,
#
#                 style: geo_json_bef8c9db6e91f1266ca3aed1701867b9_styler,
#             ...{
# }
#         });
#
#         function geo_json_bef8c9db6e91f1266ca3aed1701867b9_add (data) {
#             geo_json_bef8c9db6e91f1266ca3aed1701867b9
#                 .addData(data);
#         }
#             geo_json_bef8c9db6e91f1266ca3aed1701867b9_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.92186078785084, 50.965851517501946], [13.922075151697669, 50.96590065447864], [13.922154525703075, 50.9657633123222], [13.921940161856247, 50.96571417520023], [13.92186078785084, 50.965851517501946]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_bef8c9db6e91f1266ca3aed1701867b9.addTo(map_c769c052fc17e5dcc731d575922a9246);
#
#
#         function geo_json_a524d78cf428edec4d8bbaa159448093_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_a524d78cf428edec4d8bbaa159448093_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_a524d78cf428edec4d8bbaa159448093 = L.geoJson(null, {
#                 onEachFeature: geo_json_a524d78cf428edec4d8bbaa159448093_onEachFeature,
#
#                 style: geo_json_a524d78cf428edec4d8bbaa159448093_styler,
#             ...{
# }
#         });
#
#         function geo_json_a524d78cf428edec4d8bbaa159448093_add (data) {
#             geo_json_a524d78cf428edec4d8bbaa159448093
#                 .addData(data);
#         }
#             geo_
