# %%
import sys

sys.path.insert(0, '..')

# %%
from morpheus.project.types.discretization.spatial import Rotation, LengthUnit, Grid
from morpheus.project.types.geometry import Polygon

polygon = Polygon(
  type='Polygon',
  coordinates=[[
    (13.922514437551428, 50.964720483303836),
    (13.925250781947113, 50.965228748412386),
    (13.925036413951403, 50.96623732041704),
    (13.92222441026388, 50.96609040370362),
    (13.922514437551428, 50.964720483303836)
  ]]
)

rotation = Rotation(20)
length_unit = LengthUnit.meters()
relative_col_coordinates = [0, 0.1, 0.21, 0.22, 0.23, 0.24, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
relative_row_coordinates = [0, 0.2, 0.21, 0.22, 0.23, 0.24, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 1]

grid = Grid.from_polygon_with_relative_coordinates(
  polygon=polygon,
  relative_col_coordinates=relative_col_coordinates,
  relative_row_coordinates=relative_row_coordinates,
  rotation=rotation,
)
polygon
# Out:
# Polygon(coordinates=[[(13.922514437551428, 50.964720483303836), (13.925250781947113, 50.965228748412386), (13.925036413951403, 50.96623732041704), (13.92222441026388, 50.96609040370362), (13.922514437551428, 50.964720483303836)]], type='Polygon')

# %%
import folium

m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

cell_geometries = grid.get_wgs_cell_geometries()

n_x = grid.n_cols()
n_y = grid.n_rows()

for col in range(n_x):
  for row in range(n_y):
    cell_geometry = cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson()).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5542cda9d5d0229d2136aa8d3130f915 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5542cda9d5d0229d2136aa8d3130f915&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5542cda9d5d0229d2136aa8d3130f915 = L.map(
#                 &quot;map_5542cda9d5d0229d2136aa8d3130f915&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96b39d01d663f4a1e8a378f179850c21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_96b39d01d663f4a1e8a378f179850c21.addTo(map_5542cda9d5d0229d2136aa8d3130f915);
#
#
#
#         function geo_json_6ff4b501ef48d5a4ab3edb78d781b391_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6ff4b501ef48d5a4ab3edb78d781b391 = L.geoJson(null, {
#                 onEachFeature: geo_json_6ff4b501ef48d5a4ab3edb78d781b391_onEachFeature,
#
#         });
#
#         function geo_json_6ff4b501ef48d5a4ab3edb78d781b391_add (data) {
#             geo_json_6ff4b501ef48d5a4ab3edb78d781b391
#                 .addData(data);
#         }
#             geo_json_6ff4b501ef48d5a4ab3edb78d781b391_add({&quot;coordinates&quot;: [[[13.921781413845427, 50.96598885939762], [13.92208151722892, 50.966057649571255], [13.922240265239738, 50.96578296578065], [13.921940161856242, 50.96571417520025], [13.921781413845427, 50.96598885939762]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#             geo_json_6ff4b501ef48d5a4ab3edb78d781b391.addTo(map_5542cda9d5d0229d2136aa8d3130f915);
#
#
#
#         function geo_json_4f2234300723098664a0ce2dc3329056_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4f2234300723098664a0ce2dc3329056 = L.geoJson(null, {
#                 onEachFeature: geo_json_4f2234300723098664a0ce2dc3329056_onEachFeature,
#
#         });
#
#         function geo_json_4f2234300723098664a0ce2dc3329056_add (data) {
#             geo_json_4f2234300723098664a0ce2dc3329056
#                 .addData(data);
#         }
#             geo_json_4f2234300723098664a0ce2dc3329056_add({&quot;coordinates&quot;: [[[13.921940161856242, 50.96571417520025], [13.922240265239738, 50.96578296578065], [13.92224820264028, 50.96576923154848], [13.921948099256783, 50.96570044094774], [13.921940161856242, 50.96571417520025]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#             geo_json_4f2234300723098664a0ce2dc3329056.addTo(map_5542cda9d5d0229d2136aa8d3130f915);
#
#
#
#         function geo_json_7a9c027ac497a6d4822499db988cf080_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7a9c027ac497a6d4822499db988cf080 = L.geoJson(null, {
#                 onEachFeature: geo_json_7a9c027ac497a6d4822499db988cf080_onEachFeature,
#
#         });
#
#         function geo_json_7a9c027ac497a6d4822499db988cf080_add (data) {
#             geo_json_7a9c027ac497a6d4822499db988cf080
#                 .addData(data);
#         }
#             geo_json_7a9c027ac497a6d4822499db988cf080_add({&quot;coordinates&quot;: [[[13.921948099256783, 50.96570044094774], [13.92224820264028, 50.96576923154848], [13.92225614004082, 50.96575549731225], [13.921956036657324, 50.965686706691166], [13.921948099256783, 50.96570044094774]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#             geo_json_7a9c027ac497a6d4822499db988cf080.addTo(map_5542cda9d5d0229d2136aa8d3130f915);
#
#
#
#         function geo_json_1f27b047df6570d365b66273148edac7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1f27b047df6570d365b66273148edac7 = L.geoJson(null, {
#                 onEachFeature: geo_json_1f27b047df6570d365b66273148edac7_onEachFeature,
#
#         });
#
#         function geo_json_1f27b047df6570d365b66273148edac7_add (data) {
#             geo_json_1f27b047df6570d365b66273148edac7
#                 .addData(data);
#         }
#             geo_json_1f27b047df6570d365b66273148edac7_add({&quot;coordinates&quot;: [[[13.921956036657324, 50.965686706691166], [13.92225614004082, 50.96575549731225], [13.92226407744136, 50.96574176307197], [13.921963974057865, 50.965672972430546], [13.921956036657324, 50.965686706691166]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#             geo_json_1f27b047df6570d365b66273148edac7.addTo(map_5542cda9d5d0229d2136aa8d3130f915);
#
#
#
#         function geo_json_36754fa1951b3faaf01b3d5fce4802a1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_36754fa1951b3faaf01b3d5fce4802a1 = L.geoJson(null, {
#                 onEachFeature: geo_json_36754fa1951b3faaf01b3d5fce4802a1_onEachFeature,

# %%
# Calculate and display cartesian Grid from Grid

cartesian_grid = grid.to_cartesian_grid(grid.n_cols())
cell_geometries = cartesian_grid.get_wgs_cell_geometries()

n_x = cartesian_grid.n_cols()
n_y = cartesian_grid.n_rows()

for col in range(n_x):
  for row in range(n_y):
    cell_geometry = cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson()).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5542cda9d5d0229d2136aa8d3130f915 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5542cda9d5d0229d2136aa8d3130f915&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5542cda9d5d0229d2136aa8d3130f915 = L.map(
#                 &quot;map_5542cda9d5d0229d2136aa8d3130f915&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96b39d01d663f4a1e8a378f179850c21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_96b39d01d663f4a1e8a378f179850c21.addTo(map_5542cda9d5d0229d2136aa8d3130f915);
#
#
#
#         function geo_json_6ff4b501ef48d5a4ab3edb78d781b391_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6ff4b501ef48d5a4ab3edb78d781b391 = L.geoJson(null, {
#                 onEachFeature: geo_json_6ff4b501ef48d5a4ab3edb78d781b391_onEachFeature,
#
#         });
#
#         function geo_json_6ff4b501ef48d5a4ab3edb78d781b391_add (data) {
#             geo_json_6ff4b501ef48d5a4ab3edb78d781b391
#                 .addData(data);
#         }
#             geo_json_6ff4b501ef48d5a4ab3edb78d781b391_add({&quot;coordinates&quot;: [[[13.921781413845427, 50.96598885939762], [13.92208151722892, 50.966057649571255], [13.922240265239738, 50.96578296578065], [13.921940161856242, 50.96571417520025], [13.921781413845427, 50.96598885939762]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#             geo_json_6ff4b501ef48d5a4ab3edb78d781b391.addTo(map_5542cda9d5d0229d2136aa8d3130f915);
#
#
#
#         function geo_json_4f2234300723098664a0ce2dc3329056_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4f2234300723098664a0ce2dc3329056 = L.geoJson(null, {
#                 onEachFeature: geo_json_4f2234300723098664a0ce2dc3329056_onEachFeature,
#
#         });
#
#         function geo_json_4f2234300723098664a0ce2dc3329056_add (data) {
#             geo_json_4f2234300723098664a0ce2dc3329056
#                 .addData(data);
#         }
#             geo_json_4f2234300723098664a0ce2dc3329056_add({&quot;coordinates&quot;: [[[13.921940161856242, 50.96571417520025], [13.922240265239738, 50.96578296578065], [13.92224820264028, 50.96576923154848], [13.921948099256783, 50.96570044094774], [13.921940161856242, 50.96571417520025]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#             geo_json_4f2234300723098664a0ce2dc3329056.addTo(map_5542cda9d5d0229d2136aa8d3130f915);
#
#
#
#         function geo_json_7a9c027ac497a6d4822499db988cf080_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7a9c027ac497a6d4822499db988cf080 = L.geoJson(null, {
#                 onEachFeature: geo_json_7a9c027ac497a6d4822499db988cf080_onEachFeature,
#
#         });
#
#         function geo_json_7a9c027ac497a6d4822499db988cf080_add (data) {
#             geo_json_7a9c027ac497a6d4822499db988cf080
#                 .addData(data);
#         }
#             geo_json_7a9c027ac497a6d4822499db988cf080_add({&quot;coordinates&quot;: [[[13.921948099256783, 50.96570044094774], [13.92224820264028, 50.96576923154848], [13.92225614004082, 50.96575549731225], [13.921956036657324, 50.965686706691166], [13.921948099256783, 50.96570044094774]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#             geo_json_7a9c027ac497a6d4822499db988cf080.addTo(map_5542cda9d5d0229d2136aa8d3130f915);
#
#
#
#         function geo_json_1f27b047df6570d365b66273148edac7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1f27b047df6570d365b66273148edac7 = L.geoJson(null, {
#                 onEachFeature: geo_json_1f27b047df6570d365b66273148edac7_onEachFeature,
#
#         });
#
#         function geo_json_1f27b047df6570d365b66273148edac7_add (data) {
#             geo_json_1f27b047df6570d365b66273148edac7
#                 .addData(data);
#         }
#             geo_json_1f27b047df6570d365b66273148edac7_add({&quot;coordinates&quot;: [[[13.921956036657324, 50.965686706691166], [13.92225614004082, 50.96575549731225], [13.92226407744136, 50.96574176307197], [13.921963974057865, 50.965672972430546], [13.921956036657324, 50.965686706691166]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#             geo_json_1f27b047df6570d365b66273148edac7.addTo(map_5542cda9d5d0229d2136aa8d3130f915);
#
#
#
#         function geo_json_36754fa1951b3faaf01b3d5fce4802a1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_36754fa1951b3faaf01b3d5fce4802a1 = L.geoJson(null, {
#                 onEachFeature: geo_json_36754fa1951b3faaf01b3d5fce4802a1_onEachFeature,

# %%
# Calculate and display rotated Grid from Grid

m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

grid_cell_geometries = grid.get_wgs_cell_geometries()
grid_n_x = grid.n_cols()
grid_n_y = grid.n_rows()

style = {"weight": 1, "color": "blue", "fillOpacity": 0}
for col in range(grid_n_x):
  for row in range(grid_n_y):
    cell_geometry = grid_cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson(), style_function=lambda x: style).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_670cfab127b52ee2cefc3175accc91d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_670cfab127b52ee2cefc3175accc91d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_670cfab127b52ee2cefc3175accc91d5 = L.map(
#                 &quot;map_670cfab127b52ee2cefc3175accc91d5&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e228bea9669399730132b9edf83b2fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4e228bea9669399730132b9edf83b2fa.addTo(map_670cfab127b52ee2cefc3175accc91d5);
#
#
#         function geo_json_839a081df0a173d604605c173f856937_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_839a081df0a173d604605c173f856937_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_839a081df0a173d604605c173f856937 = L.geoJson(null, {
#                 onEachFeature: geo_json_839a081df0a173d604605c173f856937_onEachFeature,
#
#                 style: geo_json_839a081df0a173d604605c173f856937_styler,
#         });
#
#         function geo_json_839a081df0a173d604605c173f856937_add (data) {
#             geo_json_839a081df0a173d604605c173f856937
#                 .addData(data);
#         }
#             geo_json_839a081df0a173d604605c173f856937_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921781413845427, 50.96598885939762], [13.92208151722892, 50.966057649571255], [13.922240265239738, 50.96578296578065], [13.921940161856242, 50.96571417520025], [13.921781413845427, 50.96598885939762]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_839a081df0a173d604605c173f856937.addTo(map_670cfab127b52ee2cefc3175accc91d5);
#
#
#         function geo_json_83615fc82d486b3bd659340a8ccda39b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_83615fc82d486b3bd659340a8ccda39b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_83615fc82d486b3bd659340a8ccda39b = L.geoJson(null, {
#                 onEachFeature: geo_json_83615fc82d486b3bd659340a8ccda39b_onEachFeature,
#
#                 style: geo_json_83615fc82d486b3bd659340a8ccda39b_styler,
#         });
#
#         function geo_json_83615fc82d486b3bd659340a8ccda39b_add (data) {
#             geo_json_83615fc82d486b3bd659340a8ccda39b
#                 .addData(data);
#         }
#             geo_json_83615fc82d486b3bd659340a8ccda39b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921940161856242, 50.96571417520025], [13.922240265239738, 50.96578296578065], [13.92224820264028, 50.96576923154848], [13.921948099256783, 50.96570044094774], [13.921940161856242, 50.96571417520025]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_83615fc82d486b3bd659340a8ccda39b.addTo(map_670cfab127b52ee2cefc3175accc91d5);
#
#
#         function geo_json_975b5ce44b145d348fec0987bceddee6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_975b5ce44b145d348fec0987bceddee6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_975b5ce44b145d348fec0987bceddee6 = L.geoJson(null, {
#                 onEachFeature: geo_json_975b5ce44b145d348fec0987bceddee6_onEachFeature,
#
#                 style: geo_json_975b5ce44b145d348fec0987bceddee6_styler,
#         });
#
#         function geo_json_975b5ce44b145d348fec0987bceddee6_add (data) {
#             geo_json_975b5ce44b145d348fec0987bceddee6
#                 .addData(data);
#         }
#             geo_json_975b5ce44b145d348fec0987bceddee6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921948099256783, 50.96570044094774], [13.92224820264028, 50.96576923154848], [13.92225614004082, 50.96575549731225], [13.921956036657324, 50.965686706691166], [13.921948099256783, 50.96570044094774]]], &quot;type&quot;:

# %%
m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

rotated_grid_with_equal_cells = grid.to_grid_with_equal_cells(n_cols=grid_n_x)
rotated_grid_cell_geometries = rotated_grid_with_equal_cells.get_wgs_cell_geometries()

rotated_grid_n_x = rotated_grid_with_equal_cells.n_cols()
rotated_grid_n_y = rotated_grid_with_equal_cells.n_rows()

style = {"weight": 1.5, "color": "red", "fillOpacity": 0}
for col in range(rotated_grid_n_x):
  for row in range(rotated_grid_n_y):
    cell_geometry = rotated_grid_cell_geometries[row][col]
    m.add_child(folium.GeoJson(cell_geometry.as_geojson(), style_function=lambda x: style))
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78e1b9c35d1d84491e4b18dce3f4f86b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78e1b9c35d1d84491e4b18dce3f4f86b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78e1b9c35d1d84491e4b18dce3f4f86b = L.map(
#                 &quot;map_78e1b9c35d1d84491e4b18dce3f4f86b&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78001415bcfc9a4994e84099732fb538 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_78001415bcfc9a4994e84099732fb538.addTo(map_78e1b9c35d1d84491e4b18dce3f4f86b);
#
#
#         function geo_json_9530b32558fa6270e96319d67a5654a8_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_9530b32558fa6270e96319d67a5654a8_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9530b32558fa6270e96319d67a5654a8 = L.geoJson(null, {
#                 onEachFeature: geo_json_9530b32558fa6270e96319d67a5654a8_onEachFeature,
#
#                 style: geo_json_9530b32558fa6270e96319d67a5654a8_styler,
#         });
#
#         function geo_json_9530b32558fa6270e96319d67a5654a8_add (data) {
#             geo_json_9530b32558fa6270e96319d67a5654a8
#                 .addData(data);
#         }
#             geo_json_9530b32558fa6270e96319d67a5654a8_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921781413845427, 50.96598885939762], [13.92199577769226, 50.96603799622904], [13.922075151697666, 50.96590065447865], [13.92186078785084, 50.965851517501946], [13.921781413845427, 50.96598885939762]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_9530b32558fa6270e96319d67a5654a8.addTo(map_78e1b9c35d1d84491e4b18dce3f4f86b);
#
#
#         function geo_json_f945feebcc7b40ca7e254600b47b075e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_f945feebcc7b40ca7e254600b47b075e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f945feebcc7b40ca7e254600b47b075e = L.geoJson(null, {
#                 onEachFeature: geo_json_f945feebcc7b40ca7e254600b47b075e_onEachFeature,
#
#                 style: geo_json_f945feebcc7b40ca7e254600b47b075e_styler,
#         });
#
#         function geo_json_f945feebcc7b40ca7e254600b47b075e_add (data) {
#             geo_json_f945feebcc7b40ca7e254600b47b075e
#                 .addData(data);
#         }
#             geo_json_f945feebcc7b40ca7e254600b47b075e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.92186078785084, 50.965851517501946], [13.922075151697666, 50.96590065447865], [13.922154525703073, 50.96576331232222], [13.921940161856247, 50.96571417520025], [13.92186078785084, 50.965851517501946]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_f945feebcc7b40ca7e254600b47b075e.addTo(map_78e1b9c35d1d84491e4b18dce3f4f86b);
#
#
#         function geo_json_bec358163de6360313e54f3e37c60aec_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_bec358163de6360313e54f3e37c60aec_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bec358163de6360313e54f3e37c60aec = L.geoJson(null, {
#                 onEachFeature: geo_json_bec358163de6360313e54f3e37c60aec_onEachFeature,
#
#                 style: geo_json_bec358163de6360313e54f3e37c60aec_styler,
#         });
#
#         function geo_json_bec358163de6360313e54f3e37c60aec_add (data) {
#             geo_json_bec358163de6360313e54f3e37c60aec
#                 .addData(data);
#         }
#             geo_json_bec358163de6360313e54f3e37c60aec_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520025], [13.922154525703073, 50.96576331232222], [13.922233899708484, 50.965625969759714], [13.922019535861654, 50.965576832492474], [13.921940161856247, 50.96571417520025]]], &quot;type&
