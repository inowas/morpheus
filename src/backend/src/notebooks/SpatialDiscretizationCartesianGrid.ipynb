# %%
import sys

sys.path.insert(0, '..')

# %%
from morpheus.project.types.discretization.spatial import Rotation, LengthUnit, Grid
from morpheus.project.types.geometry import Polygon

polygon = Polygon(
  type='Polygon',
  coordinates=[[
    (13.922514437551428, 50.964720483303836),
    (13.925250781947113, 50.965228748412386),
    (13.925036413951403, 50.96623732041704),
    (13.92222441026388, 50.96609040370362),
    (13.922514437551428, 50.964720483303836)
  ]]
)

rotation = Rotation(20)
length_unit = LengthUnit.meters()
relative_col_coordinates = [0, 0.1, 0.21, 0.22, 0.23, 0.24, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
relative_row_coordinates = [0, 0.2, 0.21, 0.22, 0.23, 0.24, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 1]

grid = Grid.from_polygon_with_relative_coordinates(
  polygon=polygon,
  relative_col_coordinates=relative_col_coordinates,
  relative_row_coordinates=relative_row_coordinates,
  rotation=rotation,
)
polygon
# Out:
# Polygon(coordinates=[[(13.922514437551428, 50.964720483303836), (13.925250781947113, 50.965228748412386), (13.925036413951403, 50.96623732041704), (13.92222441026388, 50.96609040370362), (13.922514437551428, 50.964720483303836)]], type='Polygon')

# %%
import folium

m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

cell_geometries = grid.get_wgs_cell_geometries()

n_x = grid.n_cols()
n_y = grid.n_rows()

for col in range(n_x):
  for row in range(n_y):
    cell_geometry = cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson()).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_579debbdf9e3af520698cd5623261b5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_579debbdf9e3af520698cd5623261b5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_579debbdf9e3af520698cd5623261b5b = L.map(
#                 &quot;map_579debbdf9e3af520698cd5623261b5b&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cf648186c8b10d6c3990f8700c4f978 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2cf648186c8b10d6c3990f8700c4f978.addTo(map_579debbdf9e3af520698cd5623261b5b);
#
#
#
#         function geo_json_e8112a581b240bb2a128aeb69acdeecb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e8112a581b240bb2a128aeb69acdeecb = L.geoJson(null, {
#                 onEachFeature: geo_json_e8112a581b240bb2a128aeb69acdeecb_onEachFeature,
#
#         });
#
#         function geo_json_e8112a581b240bb2a128aeb69acdeecb_add (data) {
#             geo_json_e8112a581b240bb2a128aeb69acdeecb
#                 .addData(data);
#         }
#             geo_json_e8112a581b240bb2a128aeb69acdeecb_add({&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_e8112a581b240bb2a128aeb69acdeecb.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_e8112a581b240bb2a128aeb69acdeecb.addTo(map_579debbdf9e3af520698cd5623261b5b);
#
#
#
#         function geo_json_511674811728a8480e4d62bec85edf8a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_511674811728a8480e4d62bec85edf8a = L.geoJson(null, {
#                 onEachFeature: geo_json_511674811728a8480e4d62bec85edf8a_onEachFeature,
#
#         });
#
#         function geo_json_511674811728a8480e4d62bec85edf8a_add (data) {
#             geo_json_511674811728a8480e4d62bec85edf8a
#                 .addData(data);
#         }
#             geo_json_511674811728a8480e4d62bec85edf8a_add({&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_511674811728a8480e4d62bec85edf8a.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_511674811728a8480e4d62bec85edf8a.addTo(map_579debbdf9e3af520698cd5623261b5b);
#
#
#
#         function geo_json_3e583e6a327fa334e9d08de67e375eeb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3e583e6a327fa334e9d08de67e375eeb = L.geoJson(null, {
#                 onEachFeature: geo_json_3e583e6a327fa334e9d08de67e375eeb_onEachFeature,
#
#         });
#
#         function geo_json_3e583e6a327fa334e9d08de67e375eeb_add (data) {
#             geo_json_3e583e6a327fa334e9d08de67e375eeb
#                 .addData(data);
#         }
#             geo_json_3e583e6a327fa334e9d08de67e375eeb_add({&quot;coordinates&quot;: [[[13.921948099256786, 50.96570044094772], [13.922248202640281, 50.965769231548464], [13.922256140040822, 50.96575549731223], [13.921956036657328, 50.96568670669115], [13.921948099256786, 50.96570044094772]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_3e583e6a327fa334e9d08de67e375eeb.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_3e583e6a327fa334e9d08de67e375eeb.addTo(map_579debbdf9e3af520698cd5623261b5b);
#
#
#
#         function geo_json_98f5566b60dc5f2fc1581deae2584ed7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_98f5566b60dc5f2fc1581deae2584ed7 = L.geoJson(null, {
#                 onEachFeature: geo_json_98f5566b60dc5f2fc1581deae2584ed7_onEachFeature,
#
#         });
#
#         function geo_json_98f5566b60dc5f2fc1581deae2584ed7_add (data) {
#             geo_json_98f5566b60dc5f2fc1581deae2584ed7
#                 .addData(data);
#         }
#             geo_json_98f5566b60dc5f2fc1581deae2584ed7_add({&quot;coordinates&quot;: [[[13.921956036657328, 50.96568670669115], [13.922256140040822, 50.96575549731223], [13.922264077441364, 50.965741763071954], [13.921963974057869, 50.965672972430525], [13.921956036657328, 50.96568670669115]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_98f5566b60dc5f2fc1581deae2584ed7.setStyle(function(feature) {return feature.

# %%
# Calculate and display cartesian Grid from Grid

cartesian_grid = grid.to_cartesian_grid(grid.n_cols())
cell_geometries = cartesian_grid.get_wgs_cell_geometries()

n_x = cartesian_grid.n_cols()
n_y = cartesian_grid.n_rows()

for col in range(n_x):
  for row in range(n_y):
    cell_geometry = cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson()).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_579debbdf9e3af520698cd5623261b5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_579debbdf9e3af520698cd5623261b5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_579debbdf9e3af520698cd5623261b5b = L.map(
#                 &quot;map_579debbdf9e3af520698cd5623261b5b&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cf648186c8b10d6c3990f8700c4f978 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2cf648186c8b10d6c3990f8700c4f978.addTo(map_579debbdf9e3af520698cd5623261b5b);
#
#
#
#         function geo_json_e8112a581b240bb2a128aeb69acdeecb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e8112a581b240bb2a128aeb69acdeecb = L.geoJson(null, {
#                 onEachFeature: geo_json_e8112a581b240bb2a128aeb69acdeecb_onEachFeature,
#
#         });
#
#         function geo_json_e8112a581b240bb2a128aeb69acdeecb_add (data) {
#             geo_json_e8112a581b240bb2a128aeb69acdeecb
#                 .addData(data);
#         }
#             geo_json_e8112a581b240bb2a128aeb69acdeecb_add({&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_e8112a581b240bb2a128aeb69acdeecb.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_e8112a581b240bb2a128aeb69acdeecb.addTo(map_579debbdf9e3af520698cd5623261b5b);
#
#
#
#         function geo_json_511674811728a8480e4d62bec85edf8a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_511674811728a8480e4d62bec85edf8a = L.geoJson(null, {
#                 onEachFeature: geo_json_511674811728a8480e4d62bec85edf8a_onEachFeature,
#
#         });
#
#         function geo_json_511674811728a8480e4d62bec85edf8a_add (data) {
#             geo_json_511674811728a8480e4d62bec85edf8a
#                 .addData(data);
#         }
#             geo_json_511674811728a8480e4d62bec85edf8a_add({&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_511674811728a8480e4d62bec85edf8a.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_511674811728a8480e4d62bec85edf8a.addTo(map_579debbdf9e3af520698cd5623261b5b);
#
#
#
#         function geo_json_3e583e6a327fa334e9d08de67e375eeb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3e583e6a327fa334e9d08de67e375eeb = L.geoJson(null, {
#                 onEachFeature: geo_json_3e583e6a327fa334e9d08de67e375eeb_onEachFeature,
#
#         });
#
#         function geo_json_3e583e6a327fa334e9d08de67e375eeb_add (data) {
#             geo_json_3e583e6a327fa334e9d08de67e375eeb
#                 .addData(data);
#         }
#             geo_json_3e583e6a327fa334e9d08de67e375eeb_add({&quot;coordinates&quot;: [[[13.921948099256786, 50.96570044094772], [13.922248202640281, 50.965769231548464], [13.922256140040822, 50.96575549731223], [13.921956036657328, 50.96568670669115], [13.921948099256786, 50.96570044094772]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_3e583e6a327fa334e9d08de67e375eeb.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_3e583e6a327fa334e9d08de67e375eeb.addTo(map_579debbdf9e3af520698cd5623261b5b);
#
#
#
#         function geo_json_98f5566b60dc5f2fc1581deae2584ed7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_98f5566b60dc5f2fc1581deae2584ed7 = L.geoJson(null, {
#                 onEachFeature: geo_json_98f5566b60dc5f2fc1581deae2584ed7_onEachFeature,
#
#         });
#
#         function geo_json_98f5566b60dc5f2fc1581deae2584ed7_add (data) {
#             geo_json_98f5566b60dc5f2fc1581deae2584ed7
#                 .addData(data);
#         }
#             geo_json_98f5566b60dc5f2fc1581deae2584ed7_add({&quot;coordinates&quot;: [[[13.921956036657328, 50.96568670669115], [13.922256140040822, 50.96575549731223], [13.922264077441364, 50.965741763071954], [13.921963974057869, 50.965672972430525], [13.921956036657328, 50.96568670669115]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_98f5566b60dc5f2fc1581deae2584ed7.setStyle(function(feature) {return feature.

# %%
# Calculate and display rotated Grid from Grid

m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

grid_cell_geometries = grid.get_wgs_cell_geometries()
grid_n_x = grid.n_cols()
grid_n_y = grid.n_rows()

style = {"weight": 1, "color": "blue", "fillOpacity": 0}
for col in range(grid_n_x):
  for row in range(grid_n_y):
    cell_geometry = grid_cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson(), style_function=lambda x: style).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f208c1adfbc46b81c7010c59e08bcc2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f208c1adfbc46b81c7010c59e08bcc2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f208c1adfbc46b81c7010c59e08bcc2 = L.map(
#                 &quot;map_5f208c1adfbc46b81c7010c59e08bcc2&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c193c216bbb7ceae93b258418f6e43b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c193c216bbb7ceae93b258418f6e43b8.addTo(map_5f208c1adfbc46b81c7010c59e08bcc2);
#
#
#         function geo_json_d601e41c6e3669ad67a31ed34a995400_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d601e41c6e3669ad67a31ed34a995400_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d601e41c6e3669ad67a31ed34a995400 = L.geoJson(null, {
#                 onEachFeature: geo_json_d601e41c6e3669ad67a31ed34a995400_onEachFeature,
#
#                 style: geo_json_d601e41c6e3669ad67a31ed34a995400_styler,
#         });
#
#         function geo_json_d601e41c6e3669ad67a31ed34a995400_add (data) {
#             geo_json_d601e41c6e3669ad67a31ed34a995400
#                 .addData(data);
#         }
#             geo_json_d601e41c6e3669ad67a31ed34a995400_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_d601e41c6e3669ad67a31ed34a995400.addTo(map_5f208c1adfbc46b81c7010c59e08bcc2);
#
#
#         function geo_json_befc55edf771d92ac5fe3e1c800420eb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_befc55edf771d92ac5fe3e1c800420eb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_befc55edf771d92ac5fe3e1c800420eb = L.geoJson(null, {
#                 onEachFeature: geo_json_befc55edf771d92ac5fe3e1c800420eb_onEachFeature,
#
#                 style: geo_json_befc55edf771d92ac5fe3e1c800420eb_styler,
#         });
#
#         function geo_json_befc55edf771d92ac5fe3e1c800420eb_add (data) {
#             geo_json_befc55edf771d92ac5fe3e1c800420eb
#                 .addData(data);
#         }
#             geo_json_befc55edf771d92ac5fe3e1c800420eb_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_befc55edf771d92ac5fe3e1c800420eb.addTo(map_5f208c1adfbc46b81c7010c59e08bcc2);
#
#
#         function geo_json_e589308df6b6529170e6453ccff27ec4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e589308df6b6529170e6453ccff27ec4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e589308df6b6529170e6453ccff27ec4 = L.geoJson(null, {
#                 onEachFeature: geo_json_e589308df6b6529170e6453ccff27ec4_onEachFeature,
#
#                 style: geo_json_e589308df6b6529170e6453ccff27ec4_styler,
#         });
#
#         function geo_json_e589308df6b6529170e6453ccff27ec4_add (data) {
#             geo_json_e589308df6b6529170e6453ccff27ec4
#                 .addData(data);
#         }
#             geo_json_e589308df6b6529170e6453ccff27ec4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921948099256786, 50.96570044094772], [13.922248202640281, 50.965769231548464], [13.922256140040822, 50.96575549731223], [13.921956036657328, 50.96568670669115], [13.921948099256786, 50.96570044094772]]], &quot;

# %%
m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

rotated_grid_with_equal_cells = grid.to_grid_with_equal_cells(n_cols=grid_n_x)
rotated_grid_cell_geometries = rotated_grid_with_equal_cells.get_wgs_cell_geometries()

rotated_grid_n_x = rotated_grid_with_equal_cells.n_cols()
rotated_grid_n_y = rotated_grid_with_equal_cells.n_rows()

style = {"weight": 1.5, "color": "red", "fillOpacity": 0}
for col in range(rotated_grid_n_x):
  for row in range(rotated_grid_n_y):
    cell_geometry = rotated_grid_cell_geometries[row][col]
    m.add_child(folium.GeoJson(cell_geometry.as_geojson(), style_function=lambda x: style))
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45bdc0acf3df52ec12365306b7232f7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45bdc0acf3df52ec12365306b7232f7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45bdc0acf3df52ec12365306b7232f7c = L.map(
#                 &quot;map_45bdc0acf3df52ec12365306b7232f7c&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35e199839d06920431e1e8a7725432e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_35e199839d06920431e1e8a7725432e5.addTo(map_45bdc0acf3df52ec12365306b7232f7c);
#
#
#         function geo_json_f81ec0715c53bf96defe646a23aae148_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_f81ec0715c53bf96defe646a23aae148_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f81ec0715c53bf96defe646a23aae148 = L.geoJson(null, {
#                 onEachFeature: geo_json_f81ec0715c53bf96defe646a23aae148_onEachFeature,
#
#                 style: geo_json_f81ec0715c53bf96defe646a23aae148_styler,
#         });
#
#         function geo_json_f81ec0715c53bf96defe646a23aae148_add (data) {
#             geo_json_f81ec0715c53bf96defe646a23aae148
#                 .addData(data);
#         }
#             geo_json_f81ec0715c53bf96defe646a23aae148_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.921995777692256, 50.966037996229026], [13.922075151697669, 50.96590065447864], [13.92186078785084, 50.965851517501946], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_f81ec0715c53bf96defe646a23aae148.addTo(map_45bdc0acf3df52ec12365306b7232f7c);
#
#
#         function geo_json_fc3854781f71a8854bb7d84028d793e7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_fc3854781f71a8854bb7d84028d793e7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_fc3854781f71a8854bb7d84028d793e7 = L.geoJson(null, {
#                 onEachFeature: geo_json_fc3854781f71a8854bb7d84028d793e7_onEachFeature,
#
#                 style: geo_json_fc3854781f71a8854bb7d84028d793e7_styler,
#         });
#
#         function geo_json_fc3854781f71a8854bb7d84028d793e7_add (data) {
#             geo_json_fc3854781f71a8854bb7d84028d793e7
#                 .addData(data);
#         }
#             geo_json_fc3854781f71a8854bb7d84028d793e7_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.92186078785084, 50.965851517501946], [13.922075151697669, 50.96590065447864], [13.922154525703075, 50.9657633123222], [13.921940161856247, 50.96571417520023], [13.92186078785084, 50.965851517501946]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_fc3854781f71a8854bb7d84028d793e7.addTo(map_45bdc0acf3df52ec12365306b7232f7c);
#
#
#         function geo_json_f8445b37b01f07cd7281c9e0b35fddab_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_f8445b37b01f07cd7281c9e0b35fddab_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f8445b37b01f07cd7281c9e0b35fddab = L.geoJson(null, {
#                 onEachFeature: geo_json_f8445b37b01f07cd7281c9e0b35fddab_onEachFeature,
#
#                 style: geo_json_f8445b37b01f07cd7281c9e0b35fddab_styler,
#         });
#
#         function geo_json_f8445b37b01f07cd7281c9e0b35fddab_add (data) {
#             geo_json_f8445b37b01f07cd7281c9e0b35fddab
#                 .addData(data);
#         }
#             geo_json_f8445b37b01f07cd7281c9e0b35fddab_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.922154525703075, 50.9657633123222], [13.922233899708482, 50.96562596975971], [13.922019535861654, 50.96557683249246], [13.921940161856247, 50.96571417520023]]], &quo
