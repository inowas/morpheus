# %%
import sys

sys.path.insert(0, '..')

# %%
from morpheus.project.types.discretization.spatial import Rotation, LengthUnit, Grid
from morpheus.project.types.geometry import Polygon

polygon = Polygon(
  type='Polygon',
  coordinates=[[
    (13.922514437551428, 50.964720483303836),
    (13.925250781947113, 50.965228748412386),
    (13.925036413951403, 50.96623732041704),
    (13.92222441026388, 50.96609040370362),
    (13.922514437551428, 50.964720483303836)
  ]]
)

rotation = Rotation(20)
length_unit = LengthUnit.meters()
relative_col_coordinates = [0, 0.1, 0.21, 0.22, 0.23, 0.24, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
relative_row_coordinates = [0, 0.2, 0.21, 0.22, 0.23, 0.24, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 1]

grid = Grid.from_polygon_with_relative_coordinates(
  polygon=polygon,
  relative_col_coordinates=relative_col_coordinates,
  relative_row_coordinates=relative_row_coordinates,
  rotation=rotation,
)
polygon
# Out:
# Polygon(coordinates=[[(13.922514437551428, 50.964720483303836), (13.925250781947113, 50.965228748412386), (13.925036413951403, 50.96623732041704), (13.92222441026388, 50.96609040370362), (13.922514437551428, 50.964720483303836)]], type='Polygon')

# %%
import folium

m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

cell_geometries = grid.get_wgs_cell_geometries()

n_x = grid.n_cols()
n_y = grid.n_rows()

for col in range(n_x):
  for row in range(n_y):
    cell_geometry = cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson()).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07a21bcb5d7451a531a8c128ce6dd542 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07a21bcb5d7451a531a8c128ce6dd542&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07a21bcb5d7451a531a8c128ce6dd542 = L.map(
#                 &quot;map_07a21bcb5d7451a531a8c128ce6dd542&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_819ee5a6270a1fd195bba23b5dcf8ea1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_819ee5a6270a1fd195bba23b5dcf8ea1.addTo(map_07a21bcb5d7451a531a8c128ce6dd542);
#
#
#
#         function geo_json_b7242bdaf17f84a144c2cc0a695e24a3_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_b7242bdaf17f84a144c2cc0a695e24a3 = L.geoJson(null, {
#                 onEachFeature: geo_json_b7242bdaf17f84a144c2cc0a695e24a3_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_b7242bdaf17f84a144c2cc0a695e24a3_add (data) {
#             geo_json_b7242bdaf17f84a144c2cc0a695e24a3
#                 .addData(data);
#         }
#             geo_json_b7242bdaf17f84a144c2cc0a695e24a3_add({&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_b7242bdaf17f84a144c2cc0a695e24a3.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_b7242bdaf17f84a144c2cc0a695e24a3.addTo(map_07a21bcb5d7451a531a8c128ce6dd542);
#
#
#
#         function geo_json_542d1e504a65420ffb199c63f202b2a0_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_542d1e504a65420ffb199c63f202b2a0 = L.geoJson(null, {
#                 onEachFeature: geo_json_542d1e504a65420ffb199c63f202b2a0_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_542d1e504a65420ffb199c63f202b2a0_add (data) {
#             geo_json_542d1e504a65420ffb199c63f202b2a0
#                 .addData(data);
#         }
#             geo_json_542d1e504a65420ffb199c63f202b2a0_add({&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_542d1e504a65420ffb199c63f202b2a0.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_542d1e504a65420ffb199c63f202b2a0.addTo(map_07a21bcb5d7451a531a8c128ce6dd542);
#
#
#
#         function geo_json_d6fe5d9e68af8596c4e459e250d04a35_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_d6fe5d9e68af8596c4e459e250d04a35 = L.geoJson(null, {
#                 onEachFeature: geo_json_d6fe5d9e68af8596c4e459e250d04a35_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_d6fe5d9e68af8596c4e459e250d04a35_add (data) {
#             geo_json_d6fe5d9e68af8596c4e459e250d04a35
#                 .addData(data);
#         }
#             geo_json_d6fe5d9e68af8596c4e459e250d04a35_add({&quot;coordinates&quot;: [[[13.921948099256786, 50.96570044094772], [13.922248202640281, 50.965769231548464], [13.922256140040822, 50.96575549731223], [13.921956036657328, 50.96568670669115], [13.921948099256786, 50.96570044094772]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_d6fe5d9e68af8596c4e459e250d04a35.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_d6fe5d9e68af8596c4e459e250d04a35.addTo(map_07a21bcb5d7451a531a8c128ce6dd542);
#
#
#
#         function geo_json_7104dfb24715b1eae02614c026aa50b7_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_7104dfb24715b1eae02614c026aa50b7 = L.geoJson(null, {
#                 onEachFeature: geo_json_7104dfb24715b1eae02614c026aa50b7_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_7104dfb24715b1eae02614c026aa50b7_add (data) {
#             geo_json_7104dfb24715b1eae02614c026aa50b7
#                 .addData(data);
#         }
#             geo_json_7104dfb24715b1eae02614c026aa50b7_add({&quot;coordinates&quot;

# %%
# Calculate and display cartesian Grid from Grid

cartesian_grid = grid.to_cartesian_grid(grid.n_cols())
cell_geometries = cartesian_grid.get_wgs_cell_geometries()

n_x = cartesian_grid.n_cols()
n_y = cartesian_grid.n_rows()

for col in range(n_x):
  for row in range(n_y):
    cell_geometry = cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson()).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07a21bcb5d7451a531a8c128ce6dd542 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07a21bcb5d7451a531a8c128ce6dd542&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07a21bcb5d7451a531a8c128ce6dd542 = L.map(
#                 &quot;map_07a21bcb5d7451a531a8c128ce6dd542&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_819ee5a6270a1fd195bba23b5dcf8ea1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_819ee5a6270a1fd195bba23b5dcf8ea1.addTo(map_07a21bcb5d7451a531a8c128ce6dd542);
#
#
#
#         function geo_json_b7242bdaf17f84a144c2cc0a695e24a3_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_b7242bdaf17f84a144c2cc0a695e24a3 = L.geoJson(null, {
#                 onEachFeature: geo_json_b7242bdaf17f84a144c2cc0a695e24a3_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_b7242bdaf17f84a144c2cc0a695e24a3_add (data) {
#             geo_json_b7242bdaf17f84a144c2cc0a695e24a3
#                 .addData(data);
#         }
#             geo_json_b7242bdaf17f84a144c2cc0a695e24a3_add({&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_b7242bdaf17f84a144c2cc0a695e24a3.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_b7242bdaf17f84a144c2cc0a695e24a3.addTo(map_07a21bcb5d7451a531a8c128ce6dd542);
#
#
#
#         function geo_json_542d1e504a65420ffb199c63f202b2a0_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_542d1e504a65420ffb199c63f202b2a0 = L.geoJson(null, {
#                 onEachFeature: geo_json_542d1e504a65420ffb199c63f202b2a0_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_542d1e504a65420ffb199c63f202b2a0_add (data) {
#             geo_json_542d1e504a65420ffb199c63f202b2a0
#                 .addData(data);
#         }
#             geo_json_542d1e504a65420ffb199c63f202b2a0_add({&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_542d1e504a65420ffb199c63f202b2a0.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_542d1e504a65420ffb199c63f202b2a0.addTo(map_07a21bcb5d7451a531a8c128ce6dd542);
#
#
#
#         function geo_json_d6fe5d9e68af8596c4e459e250d04a35_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_d6fe5d9e68af8596c4e459e250d04a35 = L.geoJson(null, {
#                 onEachFeature: geo_json_d6fe5d9e68af8596c4e459e250d04a35_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_d6fe5d9e68af8596c4e459e250d04a35_add (data) {
#             geo_json_d6fe5d9e68af8596c4e459e250d04a35
#                 .addData(data);
#         }
#             geo_json_d6fe5d9e68af8596c4e459e250d04a35_add({&quot;coordinates&quot;: [[[13.921948099256786, 50.96570044094772], [13.922248202640281, 50.965769231548464], [13.922256140040822, 50.96575549731223], [13.921956036657328, 50.96568670669115], [13.921948099256786, 50.96570044094772]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_d6fe5d9e68af8596c4e459e250d04a35.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_d6fe5d9e68af8596c4e459e250d04a35.addTo(map_07a21bcb5d7451a531a8c128ce6dd542);
#
#
#
#         function geo_json_7104dfb24715b1eae02614c026aa50b7_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_7104dfb24715b1eae02614c026aa50b7 = L.geoJson(null, {
#                 onEachFeature: geo_json_7104dfb24715b1eae02614c026aa50b7_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_7104dfb24715b1eae02614c026aa50b7_add (data) {
#             geo_json_7104dfb24715b1eae02614c026aa50b7
#                 .addData(data);
#         }
#             geo_json_7104dfb24715b1eae02614c026aa50b7_add({&quot;coordinates&quot;

# %%
# Calculate and display rotated Grid from Grid

m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

grid_cell_geometries = grid.get_wgs_cell_geometries()
grid_n_x = grid.n_cols()
grid_n_y = grid.n_rows()

style = {"weight": 1, "color": "blue", "fillOpacity": 0}
for col in range(grid_n_x):
  for row in range(grid_n_y):
    cell_geometry = grid_cell_geometries[row][col]
    folium.GeoJson(cell_geometry.as_geojson(), style_function=lambda x: style).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2bf29a8e2710e9221101400fd9e79ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2bf29a8e2710e9221101400fd9e79ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2bf29a8e2710e9221101400fd9e79ca = L.map(
#                 &quot;map_c2bf29a8e2710e9221101400fd9e79ca&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c695077b2191eb61cbddf799facceba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c695077b2191eb61cbddf799facceba.addTo(map_c2bf29a8e2710e9221101400fd9e79ca);
#
#
#         function geo_json_2c1ab806d07e452b33bb330c5de3b498_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2c1ab806d07e452b33bb330c5de3b498_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_2c1ab806d07e452b33bb330c5de3b498 = L.geoJson(null, {
#                 onEachFeature: geo_json_2c1ab806d07e452b33bb330c5de3b498_onEachFeature,
#
#                 style: geo_json_2c1ab806d07e452b33bb330c5de3b498_styler,
#             ...{
# }
#         });
#
#         function geo_json_2c1ab806d07e452b33bb330c5de3b498_add (data) {
#             geo_json_2c1ab806d07e452b33bb330c5de3b498
#                 .addData(data);
#         }
#             geo_json_2c1ab806d07e452b33bb330c5de3b498_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_2c1ab806d07e452b33bb330c5de3b498.addTo(map_c2bf29a8e2710e9221101400fd9e79ca);
#
#
#         function geo_json_058264d7e96a8df789801610b51b4c96_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_058264d7e96a8df789801610b51b4c96_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_058264d7e96a8df789801610b51b4c96 = L.geoJson(null, {
#                 onEachFeature: geo_json_058264d7e96a8df789801610b51b4c96_onEachFeature,
#
#                 style: geo_json_058264d7e96a8df789801610b51b4c96_styler,
#             ...{
# }
#         });
#
#         function geo_json_058264d7e96a8df789801610b51b4c96_add (data) {
#             geo_json_058264d7e96a8df789801610b51b4c96
#                 .addData(data);
#         }
#             geo_json_058264d7e96a8df789801610b51b4c96_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_058264d7e96a8df789801610b51b4c96.addTo(map_c2bf29a8e2710e9221101400fd9e79ca);
#
#
#         function geo_json_ed436f5c896fe505855c33bca91b2df7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ed436f5c896fe505855c33bca91b2df7_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_ed436f5c896fe505855c33bca91b2df7 = L.geoJson(null, {
#                 onEachFeature: geo_json_ed436f5c896fe505855c33bca91b2df7_onEachFeature,
#
#                 style: geo_json_ed436f5c896fe505855c33bca91b2df7_styler,
#             ...{
# }
#         });
#
#         function geo_json_ed436f5c896fe505855c33bca91b2df7_add (data) {
#             geo_json_ed436f5c896fe505855c33bca91b2df7
#                 .addData(data);
#         }
#             geo_json

# %%
m = folium.Map(crs="EPSG3857", zoom_start=12, location=[50.965, 13.922])

rotated_grid_with_equal_cells = grid.to_grid_with_equal_cells(n_cols=grid_n_x)
rotated_grid_cell_geometries = rotated_grid_with_equal_cells.get_wgs_cell_geometries()

rotated_grid_n_x = rotated_grid_with_equal_cells.n_cols()
rotated_grid_n_y = rotated_grid_with_equal_cells.n_rows()

style = {"weight": 1.5, "color": "red", "fillOpacity": 0}
for col in range(rotated_grid_n_x):
  for row in range(rotated_grid_n_y):
    cell_geometry = rotated_grid_cell_geometries[row][col]
    m.add_child(folium.GeoJson(cell_geometry.as_geojson(), style_function=lambda x: style))
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_247ea0770a4d06c6f86d4db00c769d61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_247ea0770a4d06c6f86d4db00c769d61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_247ea0770a4d06c6f86d4db00c769d61 = L.map(
#                 &quot;map_247ea0770a4d06c6f86d4db00c769d61&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d706b4adea91ed2745be9805c94e7d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2d706b4adea91ed2745be9805c94e7d4.addTo(map_247ea0770a4d06c6f86d4db00c769d61);
#
#
#         function geo_json_6be6c78c493c6cb5245bfafd35b2241b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_6be6c78c493c6cb5245bfafd35b2241b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_6be6c78c493c6cb5245bfafd35b2241b = L.geoJson(null, {
#                 onEachFeature: geo_json_6be6c78c493c6cb5245bfafd35b2241b_onEachFeature,
#
#                 style: geo_json_6be6c78c493c6cb5245bfafd35b2241b_styler,
#             ...{
# }
#         });
#
#         function geo_json_6be6c78c493c6cb5245bfafd35b2241b_add (data) {
#             geo_json_6be6c78c493c6cb5245bfafd35b2241b
#                 .addData(data);
#         }
#             geo_json_6be6c78c493c6cb5245bfafd35b2241b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.921995777692256, 50.966037996229026], [13.922075151697669, 50.96590065447864], [13.92186078785084, 50.965851517501946], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_6be6c78c493c6cb5245bfafd35b2241b.addTo(map_247ea0770a4d06c6f86d4db00c769d61);
#
#
#         function geo_json_cf3f7d79ec7734e936afcfe2e22fcbee_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_cf3f7d79ec7734e936afcfe2e22fcbee_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_cf3f7d79ec7734e936afcfe2e22fcbee = L.geoJson(null, {
#                 onEachFeature: geo_json_cf3f7d79ec7734e936afcfe2e22fcbee_onEachFeature,
#
#                 style: geo_json_cf3f7d79ec7734e936afcfe2e22fcbee_styler,
#             ...{
# }
#         });
#
#         function geo_json_cf3f7d79ec7734e936afcfe2e22fcbee_add (data) {
#             geo_json_cf3f7d79ec7734e936afcfe2e22fcbee
#                 .addData(data);
#         }
#             geo_json_cf3f7d79ec7734e936afcfe2e22fcbee_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.92186078785084, 50.965851517501946], [13.922075151697669, 50.96590065447864], [13.922154525703075, 50.9657633123222], [13.921940161856247, 50.96571417520023], [13.92186078785084, 50.965851517501946]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_cf3f7d79ec7734e936afcfe2e22fcbee.addTo(map_247ea0770a4d06c6f86d4db00c769d61);
#
#
#         function geo_json_ffbdb84104c0285d2805504966272320_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_ffbdb84104c0285d2805504966272320_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_ffbdb84104c0285d2805504966272320 = L.geoJson(null, {
#                 onEachFeature: geo_json_ffbdb84104c0285d2805504966272320_onEachFeature,
#
#                 style: geo_json_ffbdb84104c0285d2805504966272320_styler,
#             ...{
# }
#         });
#
#         function geo_json_ffbdb84104c0285d2805504966272320_add (data) {
#             geo_json_ffbdb84104c0285d2805504966272320
#                 .addData(data);
#         }
#             geo_
