# %%
import sys

sys.path.insert(0, '..')

# %%
from morpheus.project.types.discretization.spatial import Grid, LengthUnit, Rotation
from morpheus.project.types.geometry import Polygon

polygon = Polygon(
    type='Polygon',
    coordinates=[
        [
            (13.922514437551428, 50.964720483303836),
            (13.925250781947113, 50.965228748412386),
            (13.925036413951403, 50.96623732041704),
            (13.92222441026388, 50.96609040370362),
            (13.922514437551428, 50.964720483303836),
        ]
    ],
)

rotation = Rotation(20)
length_unit = LengthUnit.meters()
relative_col_coordinates = [0, 0.1, 0.21, 0.22, 0.23, 0.24, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
relative_row_coordinates = [0, 0.2, 0.21, 0.22, 0.23, 0.24, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 1]

grid = Grid.from_polygon_with_relative_coordinates(
    polygon=polygon,
    relative_col_coordinates=relative_col_coordinates,
    relative_row_coordinates=relative_row_coordinates,
    rotation=rotation,
)
polygon
# Out:
# Polygon(coordinates=[[(13.922514437551428, 50.964720483303836), (13.925250781947113, 50.965228748412386), (13.925036413951403, 50.96623732041704), (13.92222441026388, 50.96609040370362), (13.922514437551428, 50.964720483303836)]], type='Polygon')

# %%
import folium

m = folium.Map(crs='EPSG3857', zoom_start=12, location=[50.965, 13.922])

cell_geometries = grid.get_wgs_cell_geometries()

n_x = grid.n_cols()
n_y = grid.n_rows()

for col in range(n_x):
    for row in range(n_y):
        cell_geometry = cell_geometries[row][col]
        folium.GeoJson(cell_geometry.as_geojson()).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5754be473582330129e2e0f80e5f5c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5754be473582330129e2e0f80e5f5c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5754be473582330129e2e0f80e5f5c2 = L.map(
#                 &quot;map_d5754be473582330129e2e0f80e5f5c2&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1557f160f035a1ea0ea24a0a5439724 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1557f160f035a1ea0ea24a0a5439724.addTo(map_d5754be473582330129e2e0f80e5f5c2);
#
#
#
#         function geo_json_3b19902982ed23fe69fb12d07f41c98b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_3b19902982ed23fe69fb12d07f41c98b = L.geoJson(null, {
#                 onEachFeature: geo_json_3b19902982ed23fe69fb12d07f41c98b_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_3b19902982ed23fe69fb12d07f41c98b_add (data) {
#             geo_json_3b19902982ed23fe69fb12d07f41c98b
#                 .addData(data);
#         }
#             geo_json_3b19902982ed23fe69fb12d07f41c98b_add({&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_3b19902982ed23fe69fb12d07f41c98b.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_3b19902982ed23fe69fb12d07f41c98b.addTo(map_d5754be473582330129e2e0f80e5f5c2);
#
#
#
#         function geo_json_acd38500142f2d9319081e71c5c4656b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_acd38500142f2d9319081e71c5c4656b = L.geoJson(null, {
#                 onEachFeature: geo_json_acd38500142f2d9319081e71c5c4656b_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_acd38500142f2d9319081e71c5c4656b_add (data) {
#             geo_json_acd38500142f2d9319081e71c5c4656b
#                 .addData(data);
#         }
#             geo_json_acd38500142f2d9319081e71c5c4656b_add({&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_acd38500142f2d9319081e71c5c4656b.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_acd38500142f2d9319081e71c5c4656b.addTo(map_d5754be473582330129e2e0f80e5f5c2);
#
#
#
#         function geo_json_f070ea875856a9d80c7730b0092a6ff2_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_f070ea875856a9d80c7730b0092a6ff2 = L.geoJson(null, {
#                 onEachFeature: geo_json_f070ea875856a9d80c7730b0092a6ff2_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_f070ea875856a9d80c7730b0092a6ff2_add (data) {
#             geo_json_f070ea875856a9d80c7730b0092a6ff2
#                 .addData(data);
#         }
#             geo_json_f070ea875856a9d80c7730b0092a6ff2_add({&quot;coordinates&quot;: [[[13.921948099256786, 50.96570044094772], [13.922248202640281, 50.965769231548464], [13.922256140040822, 50.96575549731223], [13.921956036657328, 50.96568670669115], [13.921948099256786, 50.96570044094772]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_f070ea875856a9d80c7730b0092a6ff2.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_f070ea875856a9d80c7730b0092a6ff2.addTo(map_d5754be473582330129e2e0f80e5f5c2);
#
#
#
#         function geo_json_4a45361b622d074f24d0ecc3baf10aa5_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_4a45361b622d074f24d0ecc3baf10aa5 = L.geoJson(null, {
#                 onEachFeature: geo_json_4a45361b622d074f24d0ecc3baf10aa5_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_4a45361b622d074f24d0ecc3baf10aa5_add (data) {
#             geo_json_4a45361b622d074f24d0ecc3baf10aa5
#                 .addData(data);
#         }
#             geo_json_4a45361b622d074f24d0ecc3baf10aa5_add({&quot;coordinates&quot;

# %%
# Calculate and display cartesian Grid from Grid

cartesian_grid = grid.to_cartesian_grid(grid.n_cols())
cell_geometries = cartesian_grid.get_wgs_cell_geometries()

n_x = cartesian_grid.n_cols()
n_y = cartesian_grid.n_rows()

for col in range(n_x):
    for row in range(n_y):
        cell_geometry = cell_geometries[row][col]
        folium.GeoJson(cell_geometry.as_geojson()).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5754be473582330129e2e0f80e5f5c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5754be473582330129e2e0f80e5f5c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5754be473582330129e2e0f80e5f5c2 = L.map(
#                 &quot;map_d5754be473582330129e2e0f80e5f5c2&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1557f160f035a1ea0ea24a0a5439724 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1557f160f035a1ea0ea24a0a5439724.addTo(map_d5754be473582330129e2e0f80e5f5c2);
#
#
#
#         function geo_json_3b19902982ed23fe69fb12d07f41c98b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_3b19902982ed23fe69fb12d07f41c98b = L.geoJson(null, {
#                 onEachFeature: geo_json_3b19902982ed23fe69fb12d07f41c98b_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_3b19902982ed23fe69fb12d07f41c98b_add (data) {
#             geo_json_3b19902982ed23fe69fb12d07f41c98b
#                 .addData(data);
#         }
#             geo_json_3b19902982ed23fe69fb12d07f41c98b_add({&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_3b19902982ed23fe69fb12d07f41c98b.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_3b19902982ed23fe69fb12d07f41c98b.addTo(map_d5754be473582330129e2e0f80e5f5c2);
#
#
#
#         function geo_json_acd38500142f2d9319081e71c5c4656b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_acd38500142f2d9319081e71c5c4656b = L.geoJson(null, {
#                 onEachFeature: geo_json_acd38500142f2d9319081e71c5c4656b_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_acd38500142f2d9319081e71c5c4656b_add (data) {
#             geo_json_acd38500142f2d9319081e71c5c4656b
#                 .addData(data);
#         }
#             geo_json_acd38500142f2d9319081e71c5c4656b_add({&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_acd38500142f2d9319081e71c5c4656b.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_acd38500142f2d9319081e71c5c4656b.addTo(map_d5754be473582330129e2e0f80e5f5c2);
#
#
#
#         function geo_json_f070ea875856a9d80c7730b0092a6ff2_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_f070ea875856a9d80c7730b0092a6ff2 = L.geoJson(null, {
#                 onEachFeature: geo_json_f070ea875856a9d80c7730b0092a6ff2_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_f070ea875856a9d80c7730b0092a6ff2_add (data) {
#             geo_json_f070ea875856a9d80c7730b0092a6ff2
#                 .addData(data);
#         }
#             geo_json_f070ea875856a9d80c7730b0092a6ff2_add({&quot;coordinates&quot;: [[[13.921948099256786, 50.96570044094772], [13.922248202640281, 50.965769231548464], [13.922256140040822, 50.96575549731223], [13.921956036657328, 50.96568670669115], [13.921948099256786, 50.96570044094772]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_f070ea875856a9d80c7730b0092a6ff2.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_f070ea875856a9d80c7730b0092a6ff2.addTo(map_d5754be473582330129e2e0f80e5f5c2);
#
#
#
#         function geo_json_4a45361b622d074f24d0ecc3baf10aa5_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_4a45361b622d074f24d0ecc3baf10aa5 = L.geoJson(null, {
#                 onEachFeature: geo_json_4a45361b622d074f24d0ecc3baf10aa5_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_4a45361b622d074f24d0ecc3baf10aa5_add (data) {
#             geo_json_4a45361b622d074f24d0ecc3baf10aa5
#                 .addData(data);
#         }
#             geo_json_4a45361b622d074f24d0ecc3baf10aa5_add({&quot;coordinates&quot;

# %%
# Calculate and display rotated Grid from Grid

m = folium.Map(crs='EPSG3857', zoom_start=12, location=[50.965, 13.922])

grid_cell_geometries = grid.get_wgs_cell_geometries()
grid_n_x = grid.n_cols()
grid_n_y = grid.n_rows()

style = {'weight': 1, 'color': 'blue', 'fillOpacity': 0}
for col in range(grid_n_x):
    for row in range(grid_n_y):
        cell_geometry = grid_cell_geometries[row][col]
        folium.GeoJson(cell_geometry.as_geojson(), style_function=lambda x: style).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38dd45b9fc9682934f4c42d133d6726c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38dd45b9fc9682934f4c42d133d6726c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38dd45b9fc9682934f4c42d133d6726c = L.map(
#                 &quot;map_38dd45b9fc9682934f4c42d133d6726c&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35edfe87093709d6c8a58e3d49ec6830 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_35edfe87093709d6c8a58e3d49ec6830.addTo(map_38dd45b9fc9682934f4c42d133d6726c);
#
#
#         function geo_json_a736a85807637b86de99a681c43ca28b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_a736a85807637b86de99a681c43ca28b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_a736a85807637b86de99a681c43ca28b = L.geoJson(null, {
#                 onEachFeature: geo_json_a736a85807637b86de99a681c43ca28b_onEachFeature,
#
#                 style: geo_json_a736a85807637b86de99a681c43ca28b_styler,
#             ...{
# }
#         });
#
#         function geo_json_a736a85807637b86de99a681c43ca28b_add (data) {
#             geo_json_a736a85807637b86de99a681c43ca28b
#                 .addData(data);
#         }
#             geo_json_a736a85807637b86de99a681c43ca28b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.922081517228921, 50.96605764957125], [13.92224026523974, 50.96578296578064], [13.921940161856247, 50.96571417520023], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_a736a85807637b86de99a681c43ca28b.addTo(map_38dd45b9fc9682934f4c42d133d6726c);
#
#
#         function geo_json_39c3e8d2e15dcbd9aee2772c29409812_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_39c3e8d2e15dcbd9aee2772c29409812_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_39c3e8d2e15dcbd9aee2772c29409812 = L.geoJson(null, {
#                 onEachFeature: geo_json_39c3e8d2e15dcbd9aee2772c29409812_onEachFeature,
#
#                 style: geo_json_39c3e8d2e15dcbd9aee2772c29409812_styler,
#             ...{
# }
#         });
#
#         function geo_json_39c3e8d2e15dcbd9aee2772c29409812_add (data) {
#             geo_json_39c3e8d2e15dcbd9aee2772c29409812
#                 .addData(data);
#         }
#             geo_json_39c3e8d2e15dcbd9aee2772c29409812_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921940161856247, 50.96571417520023], [13.92224026523974, 50.96578296578064], [13.922248202640281, 50.965769231548464], [13.921948099256786, 50.96570044094772], [13.921940161856247, 50.96571417520023]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_39c3e8d2e15dcbd9aee2772c29409812.addTo(map_38dd45b9fc9682934f4c42d133d6726c);
#
#
#         function geo_json_5e2067175b9d05b738a21573ddb5446e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_5e2067175b9d05b738a21573ddb5446e_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_5e2067175b9d05b738a21573ddb5446e = L.geoJson(null, {
#                 onEachFeature: geo_json_5e2067175b9d05b738a21573ddb5446e_onEachFeature,
#
#                 style: geo_json_5e2067175b9d05b738a21573ddb5446e_styler,
#             ...{
# }
#         });
#
#         function geo_json_5e2067175b9d05b738a21573ddb5446e_add (data) {
#             geo_json_5e2067175b9d05b738a21573ddb5446e
#                 .addData(data);
#         }
#             geo_json

# %%
m = folium.Map(crs='EPSG3857', zoom_start=12, location=[50.965, 13.922])

rotated_grid_with_equal_cells = grid.to_grid_with_equal_cells(n_cols=grid_n_x)
rotated_grid_cell_geometries = rotated_grid_with_equal_cells.get_wgs_cell_geometries()

rotated_grid_n_x = rotated_grid_with_equal_cells.n_cols()
rotated_grid_n_y = rotated_grid_with_equal_cells.n_rows()

style = {'weight': 1.5, 'color': 'red', 'fillOpacity': 0}
for col in range(rotated_grid_n_x):
    for row in range(rotated_grid_n_y):
        cell_geometry = rotated_grid_cell_geometries[row][col]
        m.add_child(folium.GeoJson(cell_geometry.as_geojson(), style_function=lambda x: style))
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c2a9bd4dc88cd2b3b3b61a8b2aec9c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c2a9bd4dc88cd2b3b3b61a8b2aec9c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c2a9bd4dc88cd2b3b3b61a8b2aec9c5 = L.map(
#                 &quot;map_0c2a9bd4dc88cd2b3b3b61a8b2aec9c5&quot;,
#                 {
#                     center: [50.965, 13.922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f0dd8516fa058a79e54730fc5d5193a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f0dd8516fa058a79e54730fc5d5193a.addTo(map_0c2a9bd4dc88cd2b3b3b61a8b2aec9c5);
#
#
#         function geo_json_c65e1cbd83431a0cebbf6b6f3b069505_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_c65e1cbd83431a0cebbf6b6f3b069505_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_c65e1cbd83431a0cebbf6b6f3b069505 = L.geoJson(null, {
#                 onEachFeature: geo_json_c65e1cbd83431a0cebbf6b6f3b069505_onEachFeature,
#
#                 style: geo_json_c65e1cbd83431a0cebbf6b6f3b069505_styler,
#             ...{
# }
#         });
#
#         function geo_json_c65e1cbd83431a0cebbf6b6f3b069505_add (data) {
#             geo_json_c65e1cbd83431a0cebbf6b6f3b069505
#                 .addData(data);
#         }
#             geo_json_c65e1cbd83431a0cebbf6b6f3b069505_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.921781413845427, 50.965988859397605], [13.921995777692256, 50.966037996229026], [13.922075151697669, 50.96590065447864], [13.92186078785084, 50.965851517501946], [13.921781413845427, 50.965988859397605]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_c65e1cbd83431a0cebbf6b6f3b069505.addTo(map_0c2a9bd4dc88cd2b3b3b61a8b2aec9c5);
#
#
#         function geo_json_5a0bb4e973f0b309a32f7928a8b75d99_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_5a0bb4e973f0b309a32f7928a8b75d99_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_5a0bb4e973f0b309a32f7928a8b75d99 = L.geoJson(null, {
#                 onEachFeature: geo_json_5a0bb4e973f0b309a32f7928a8b75d99_onEachFeature,
#
#                 style: geo_json_5a0bb4e973f0b309a32f7928a8b75d99_styler,
#             ...{
# }
#         });
#
#         function geo_json_5a0bb4e973f0b309a32f7928a8b75d99_add (data) {
#             geo_json_5a0bb4e973f0b309a32f7928a8b75d99
#                 .addData(data);
#         }
#             geo_json_5a0bb4e973f0b309a32f7928a8b75d99_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.92186078785084, 50.965851517501946], [13.922075151697669, 50.96590065447864], [13.922154525703075, 50.9657633123222], [13.921940161856247, 50.96571417520023], [13.92186078785084, 50.965851517501946]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_5a0bb4e973f0b309a32f7928a8b75d99.addTo(map_0c2a9bd4dc88cd2b3b3b61a8b2aec9c5);
#
#
#         function geo_json_b88510d9f0e60bc963ec40b939d4250c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_b88510d9f0e60bc963ec40b939d4250c_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_b88510d9f0e60bc963ec40b939d4250c = L.geoJson(null, {
#                 onEachFeature: geo_json_b88510d9f0e60bc963ec40b939d4250c_onEachFeature,
#
#                 style: geo_json_b88510d9f0e60bc963ec40b939d4250c_styler,
#             ...{
# }
#         });
#
#         function geo_json_b88510d9f0e60bc963ec40b939d4250c_add (data) {
#             geo_json_b88510d9f0e60bc963ec40b939d4250c
#                 .addData(data);
#         }
#             geo_
